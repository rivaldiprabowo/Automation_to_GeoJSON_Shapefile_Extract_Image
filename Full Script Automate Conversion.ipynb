# %% [markdown]
# # Automation Excel to GeoJSON and Shapefile

# %% [markdown]
# ## 1. Application to Export Excel into GeoJson

# %% [markdown]
# ### 1.1. Function Codes

# %%
import sys
import subprocess
import pkg_resources
import os
import re
import io
import glob
import json
from pathlib import Path

def install_requirements():
    """Install required packages if they are not already installed."""
    required = {
        'pandas': '1.0.0',
        'openpyxl': '3.0.0',
        'geopandas': '0.9.0',
        'shapely': '1.7.0',
        'openpyxl_image_loader': '1.0.0',
    }
    
    # Check what's installed
    installed = {pkg.key: pkg.version for pkg in pkg_resources.working_set}
    
    # Determine what needs to be installed
    missing = []
    update = []
    
    for package, min_version in required.items():
        if package not in installed:
            missing.append(package)
        elif pkg_resources.parse_version(installed[package]) < pkg_resources.parse_version(min_version):
            update.append(package)
    
    # If packages need to be installed or updated
    if missing or update:
        print("Some required packages are missing or need to be updated.")
        print(f"Missing: {', '.join(missing) if missing else 'None'}")
        print(f"Need update: {', '.join(update) if update else 'None'}")
        
        try:
            # Install missing packages
            if missing:
                print(f"Installing missing packages: {', '.join(missing)}")
                subprocess.check_call([sys.executable, "-m", "pip", "install"] + missing)
            
            # Update packages that need updating
            if update:
                print(f"Updating packages: {', '.join(update)}")
                subprocess.check_call([sys.executable, "-m", "pip", "install", "--upgrade"] + update)
                
            print("All required packages have been installed/updated successfully!")
            
        except Exception as e:
            print(f"Failed to install required packages: {str(e)}")
            print("Please manually install the required packages using:")
            print("pip install pandas openpyxl geopandas shapely openpyxl_image_loader")
            sys.exit(1)

install_requirements()

# Import required libraries
import pandas as pd
from openpyxl import load_workbook
import geopandas as gpd
from shapely.geometry import Point, LineString, MultiPoint
from openpyxl_image_loader import SheetImageLoader
from openpyxl.utils import get_column_letter, column_index_from_string

# Global dictionary to store image paths for each Excel file, sheet, and row
image_paths_registry = {}

def extract_images_from_excel(file_path, output_folder):
    """Extract images from columns containing specific keywords in all sheets and save them."""
    # Keywords to look for in column names
    KEYWORDS = ["DOKUMENTASI", "RAMBU", "RPPJ"]
    
    # Create subdirectories for each category directly in the main output folder
    dokumentasi_folder = os.path.join(output_folder, "Dokumentasi")
    rambu_folder = os.path.join(output_folder, "Rambu")
    rppj_folder = os.path.join(output_folder, "RPPJ")
    
    for folder in [dokumentasi_folder, rambu_folder, rppj_folder]:
        os.makedirs(folder, exist_ok=True)
    
    # Initialize image paths registry for this file
    file_name = os.path.basename(file_path)
    if file_name not in image_paths_registry:
        image_paths_registry[file_name] = {}
    
    try:
        # Extract filename from path
        file_name_clean = re.search(r'([^\\]+)\.xlsx$', file_path)
        if file_name_clean:
            file_name_clean = file_name_clean.group(1)
        else:
            file_name_clean = os.path.basename(file_path).replace('.xlsx', '')
        
        # Process each sheet independently to prevent file handle issues
        wb = load_workbook(file_path, data_only=True)
        sheet_names = wb.sheetnames.copy()  # Make a copy of sheet names before closing
        wb.close()  # Close immediately to avoid keeping file handles open
        
        successful_sheets = 0
        total_images_saved = 0
        
        # Process sheets in the order they appear in the workbook
        for sheet_idx, sheet_name in enumerate(sheet_names, 1):
            try:
                print(f"Processing sheet {sheet_idx}/{len(sheet_names)}: {sheet_name}")
                
                # Initialize image paths registry for this sheet
                if sheet_name not in image_paths_registry[file_name]:
                    image_paths_registry[file_name][sheet_name] = {}
                
                # Create a safe sheet name for filenames
                safe_sheet_name = re.sub(r'[\\/*?:"<>|]', "_", sheet_name)
                
                # Open a fresh workbook instance for each sheet
                wb = load_workbook(file_path, data_only=True)
                ws = wb[sheet_name]
                
                # Create a fresh image loader for this sheet
                image_loader = SheetImageLoader(ws)
                
                # Step 1: Extract merged column headers from rows 1-5
                # This creates a mapping from column index to full column name
                column_names = {}
                
                # Get values for rows 1-5 for each column
                for col in range(1, ws.max_column + 1):
                    col_letter = get_column_letter(col)
                    header_values = []
                    
                    for row in range(1, 6):  # Rows 1-5
                        cell_value = ws[f"{col_letter}{row}"].value
                        if cell_value:
                            header_values.append(str(cell_value).strip())
                    
                    # Combine the header parts into one name
                    if header_values:
                        column_names[col] = " ".join(header_values)
                    else:
                        column_names[col] = f"Column_{col_letter}"
                
                # Step 2: Find columns containing our keywords
                dokumentasi_columns = {}
                rambu_columns = {}
                rppj_columns = {}
                nama_rambu_column = None
                jenis_tiang_column = None
                
                # First, find all our target columns
                for col, name in column_names.items():
                    if "DOKUMENTASI" in name.upper():
                        dokumentasi_columns[col] = name
                    elif "RAMBU" in name.upper() and "NAMA RAMBU" not in name.upper():
                        rambu_columns[col] = name
                    elif "RPPJ" in name.upper():
                        rppj_columns[col] = name
                    
                    # Find the specific column for "Nama Rambu"
                    if "NAMA RAMBU" in name.upper():
                        nama_rambu_column = col
                        print(f"Found 'Nama Rambu' column: {name} (Column {get_column_letter(col)})")
                    
                    # Find the specific column for "Jenis Tiang"
                    elif "JENIS TIANG" in name.upper():
                        jenis_tiang_column = col
                        print(f"Found 'Jenis Tiang' column: {name} (Column {get_column_letter(col)})")
                
                # Track images processed for each category
                images_by_category = {
                    "dokumentasi": 0,
                    "rambu": 0,
                    "rppj": 0
                }
                
                # Process each category separately
                image_paths = {}  # Track image paths for this sheet
                
                # 1. Process DOKUMENTASI columns
                if dokumentasi_columns:
                    processed, paths = process_image_columns(
                        ws, image_loader, dokumentasi_columns, dokumentasi_folder, 
                        file_name_clean, safe_sheet_name, "dokumentasi", None, None
                    )
                    images_by_category["dokumentasi"] += processed
                    image_paths.update(paths)
                
                # 2. Process RAMBU columns (custom naming based on "Nama Rambu" column)
                if rambu_columns:
                    if nama_rambu_column is None:
                        print("⚠️ Warning: 'Nama Rambu' column not found. Using default naming for Rambu images.")
                    
                    processed, paths = process_image_columns(
                        ws, image_loader, rambu_columns, rambu_folder, 
                        file_name_clean, safe_sheet_name, "rambu", nama_rambu_column, None
                    )
                    images_by_category["rambu"] += processed
                    image_paths.update(paths)
                
                # 3. Process RPPJ columns (custom naming based on "Jenis Tiang" column)
                if rppj_columns:
                    if jenis_tiang_column is None:
                        print("⚠️ Warning: 'Jenis Tiang' column not found. Using default naming for RPPJ images.")
                    
                    processed, paths = process_image_columns(
                        ws, image_loader, rppj_columns, rppj_folder, 
                        file_name_clean, safe_sheet_name, "rppj", None, jenis_tiang_column
                    )
                    images_by_category["rppj"] += processed
                    image_paths.update(paths)
                
                # Store image paths for this sheet
                image_paths_registry[file_name][sheet_name] = image_paths
                
                total_images_saved += sum(images_by_category.values())
                
                print(f"✅ Completed sheet '{sheet_name}':")
                print(f"  - Dokumentasi: {images_by_category['dokumentasi']} images")
                print(f"  - Rambu: {images_by_category['rambu']} images")
                print(f"  - RPPJ: {images_by_category['rppj']} images")
                
                if sum(images_by_category.values()) > 0:
                    successful_sheets += 1
                
            except Exception as e:
                print(f"❌ Error processing sheet '{sheet_name}' in file '{file_name_clean}': {str(e)}")
            
            finally:
                # Always close the workbook after processing each sheet
                if 'wb' in locals() and wb is not None:
                    try:
                        wb.close()
                    except:
                        pass
        
        print(f"✅ Completed processing file: {file_name_clean}")
        print(f"  - {successful_sheets}/{len(sheet_names)} sheets processed")
        print(f"  - {total_images_saved} total images extracted")
        return True
        
    except Exception as e:
        # Handle any errors in the outer scope
        print(f"❌ Error processing file '{file_path}': {str(e)}")
        return False

def process_image_columns(ws, image_loader, target_columns, output_folder, file_name_clean, 
                          safe_sheet_name, category, nama_rambu_column, jenis_tiang_column):
    """Process images in specified columns with custom naming logic."""
    
    # Track existing image names (to avoid duplicates for Rambu)
    existing_images = {}
    
    # Track image paths for each row
    image_paths = {}
    
    # Find image cells in target columns
    image_cells = {}
    for col in target_columns:
        col_letter = get_column_letter(col)
        column_name = target_columns[col]
        
        # Make column name safe for filename
        safe_column_name = re.sub(r'[\\/*?:"<>|]', "_", column_name)
        
        # Scan rows starting from row 6
        for row in range(6, ws.max_row + 1):
            cell_address = f"{col_letter}{row}"
            if image_loader.image_in(cell_address):
                image_cells[(row, col)] = {
                    'cell_address': cell_address,
                    'column_name': safe_column_name,
                    'column_letter': col_letter,
                    'row_number': row
                }
    
    if not image_cells:
        print(f"⚠️ No images found in {category.upper()} columns, skipping...")
        return 0, {}
    
    print(f"Found {len(image_cells)} images in {category.upper()} columns")
    
    # Process images in column-first, row-second order
    successful_images = 0
    image_cells_by_column = {}
    
    # Group by column
    for (row, col), cell_info in image_cells.items():
        if col not in image_cells_by_column:
            image_cells_by_column[col] = []
        image_cells_by_column[col].append((row, cell_info))
    
    # Process each column
    for col in sorted(image_cells_by_column.keys()):
        column_letter = get_column_letter(col)
        column_name = target_columns[col]
        safe_column_name = re.sub(r'[\\/*?:"<>|]', "_", column_name)
        
        print(f"Processing {len(image_cells_by_column[col])} images in column '{column_name}'")
        
        # Process rows in order
        for row, cell_info in sorted(image_cells_by_column[col], key=lambda x: x[0]):
            cell_address = cell_info['cell_address']
            try:
                # Get the image
                img = image_loader.get(cell_address)
                
                # Generate filename based on category
                if category == "rambu" and nama_rambu_column is not None:
                    # For RAMBU: Use "Nama Rambu" column value as filename
                    nama_rambu_value = ws[f"{get_column_letter(nama_rambu_column)}{row}"].value
                    
                    if nama_rambu_value and str(nama_rambu_value).strip():
                        # Use the actual value from "Nama Rambu" column
                        safe_nama_rambu = re.sub(r'[\\/*?:"<>|]', "_", str(nama_rambu_value).strip())
                        img_filename = f"{safe_nama_rambu}.png"
                        
                        # Check if this name already exists (to avoid duplicates)
                        if img_filename in existing_images:
                            print(f"  ⚠️ Duplicate 'Nama Rambu' found: {safe_nama_rambu} - Replacing existing image")
                        
                        existing_images[img_filename] = True
                    else:
                        # Fallback to default naming if no nama_rambu value
                        print(f"  ⚠️ No 'Nama Rambu' value found for row {row}, using default naming")
                        row_identifier = f"Row{row}"
                        safe_row_identifier = re.sub(r'[\\/*?:"<>|]', "_", row_identifier)
                        img_filename = f"{file_name_clean}_Sheet_{safe_sheet_name}_Column_{safe_column_name}_{safe_row_identifier}.png"
                
                elif category == "rppj" and jenis_tiang_column is not None:
                    # For RPPJ: Use "Jenis Tiang" column value in filename
                    jenis_tiang_value = ws[f"{get_column_letter(jenis_tiang_column)}{row}"].value
                    safe_jenis_tiang = "Unknown"
                    if jenis_tiang_value and str(jenis_tiang_value).strip():
                        safe_jenis_tiang = re.sub(r'[\\/*?:"<>|]', "_", str(jenis_tiang_value).strip())
                    
                    # Get row identifier - ALWAYS use just the row number without column A value
                    row_identifier = f"Row{row}"
                    
                    safe_row_identifier = re.sub(r'[\\/*?:"<>|]', "_", row_identifier)
                    img_filename = f"{file_name_clean}_Sheet_{safe_sheet_name}_Column_{safe_jenis_tiang}_{safe_row_identifier}.png"
                
                else:
                    # Default naming for DOKUMENTASI (and fallback for others)
                    # ALWAYS use just the row number without column A value
                    row_identifier = f"Row{row}"
                    
                    safe_row_identifier = re.sub(r'[\\/*?:"<>|]', "_", row_identifier)
                    img_filename = f"{file_name_clean}_Sheet_{safe_sheet_name}_Column_{safe_column_name}_{safe_row_identifier}.png"
                
                # Save the image
                img_path = os.path.join(output_folder, img_filename)
                with io.BytesIO() as img_buffer:
                    img.save(img_buffer, format="PNG")
                    img_buffer.seek(0)
                    with open(img_path, 'wb') as f:
                        f.write(img_buffer.read())
                
                # Store image path for this row
                if row not in image_paths:
                    image_paths[row] = []
                image_paths[row].append({
                    'category': category,
                    'column_name': column_name,
                    'path': img_path
                })
                
                successful_images += 1
                print(f"  ✅ Saved: {img_filename}")
            except Exception as e:
                print(f"  ❌ Error saving image at {cell_address}: {str(e)}")
    
    return successful_images, image_paths

def unique_column_names(columns):
    """Ensure column names are unique by appending suffix."""
    seen = {}
    new_columns = []
    for col in columns:
        if col in seen:
            seen[col] += 1
            new_columns.append(f"{col}_{seen[col]}")
        else:
            seen[col] = 0
            new_columns.append(col)
    return new_columns

def clean_column_names(columns):
    """Standardize column names by capitalizing each word properly."""
    cleaned_columns = []
    seen = {}
    for col in columns:
        col = str(col).strip()
        
        # Remove columns with "Rekap" in the name
        if "rekap" in col.lower():
            continue
        
        # Fix for duplicated words (like "No No", "Detail Lokasi Detail Lokasi")
        words = col.split()
        if len(words) >= 2:
            # Check for repeated word patterns
            half_length = len(words) // 2
            if words[:half_length] == words[half_length:] and len(words) % 2 == 0:
                # If the first half matches the second half, only use the first half
                col = " ".join(words[:half_length])
        
        # Capitalize words
        col = " ".join(word.capitalize() for word in col.split())
        
        # Handle duplicates
        if col in seen:
            seen[col] += 1
            col = f"{col} {seen[col]}"
        else:
            seen[col] = 0
        
        cleaned_columns.append(col)
    return cleaned_columns

def fix_coordinates(row, lat_col, lon_col):
    """Fix latitude and longitude values that may be in the wrong format."""
    lat, lon = row[lat_col], row[lon_col]
    original_lat, original_lon = lat, lon  # Store original values for debugging
    
    # Handle string values with commas (e.g., "-69,694,951" or "1,065,663,308")
    if isinstance(lat, str):
        try:
            lat = float(lat.replace(',', ''))
        except (ValueError, AttributeError):
            lat = pd.NA
    
    if isinstance(lon, str):
        try:
            lon = float(lon.replace(',', ''))
        except (ValueError, AttributeError):
            lon = pd.NA
    
    # First attempt to detect the scale by number of digits
    if pd.notna(lat):
        lat_abs = abs(lat)
        # For values like -6448977 (which should be around -6.4 degrees)
        if 1_000_000 < lat_abs < 10_000_000 and str(int(lat_abs)).startswith(('6', '7', '8', '9')):
            lat = lat / 1_000_000
        elif lat_abs > 90:
            # General scaling rules based on magnitude
            if lat_abs > 10_000_000:  # Very large values
                lat = lat / 10_000_000
            elif lat_abs > 1_000_000:  # Large values (common for Indonesia coords)
                lat = lat / 1_000_000
            elif lat_abs > 90_000:
                lat = lat / 1_000
    
    if pd.notna(lon):
        lon_abs = abs(lon)
        # For Indonesian longitudes (usually around 106-110 degrees)
        if 100_000_000 < lon_abs < 1_500_000_000:
            lon = lon / 10_000_000
        elif lon_abs > 180:
            # General scaling rules based on magnitude
            if lon_abs > 10_000_000:
                lon = lon / 10_000_000
            elif lon_abs > 1_000_000:
                lon = lon / 1_000_000
            elif lon_abs > 180_000:
                lon = lon / 1_000
    
    # Final validation with better error reporting
    if pd.notna(lat) and (lat < -90 or lat > 90):
        print(f"Warning: Invalid latitude after correction: {lat} (original: {original_lat})")
        
        # Last attempt for specific problematic values
        if -10000 < lat < -90 or 90 < lat < 10000:
            lat = lat / 100
            print(f"  Attempting additional scaling: now {lat}")
        
        if lat < -90 or lat > 90:  # Still invalid
            lat = pd.NA
    
    if pd.notna(lon) and (lon < -180 or lon > 180):
        print(f"Warning: Invalid longitude after correction: {lon} (original: {original_lon})")
        
        # Last attempt for specific problematic values
        if -18000 < lon < -180 or 180 < lon < 18000:
            lon = lon / 100
            print(f"  Attempting additional scaling: now {lon}")
            
        if lon < -180 or lon > 180:  # Still invalid
            lon = pd.NA
        
    return pd.Series([lat, lon])

def clean_geojson(gdf, output_path):
    """Save GeoDataFrame in a clean format GeoJSON file and delete the temp file."""
    temp_path = output_path.replace(".geojson", "_temp.geojson")
    gdf.to_file(temp_path, driver="GeoJSON")

    with open(temp_path, "r", encoding="utf-8") as file:
        geojson_data = json.load(file)

    with open(output_path, "w", encoding="utf-8") as file:
        json.dump(geojson_data, file, indent=4)
    
    # Delete the temporary file
    try:
        os.remove(temp_path)
        print(f"✅ Deleted temporary file: {temp_path}")
    except Exception as e:
        print(f"⚠️ Could not delete temporary file {temp_path}: {str(e)}")

    print(f"✅ Saved: {output_path}")

def find_coordinate_columns(df, prefix, column_type):
    """Find coordinate columns with various naming patterns."""
    patterns = []
    
    if prefix == 'start':
        if column_type == 'lat':
            patterns = [
                'awal latitude', 'awal lat', 
                'koordinat latitude', 'koordinat lat',
                'latitude awal', 'lat awal',
                'latitude 1', 'lat 1'
            ]
        else:  # longitude
            patterns = [
                'awal longitude', 'awal lon', 
                'koordinat longitude', 'koordinat lon',
                'longitude awal', 'lon awal',
                'longitude 1', 'lon 1'
            ]
    else:  # end
        if column_type == 'lat':
            patterns = [
                'akhir latitude', 'akhir lat',
                'latitude akhir', 'lat akhir',
                'latitude 2', 'lat 2'
            ]
        else:  # longitude
            patterns = [
                'akhir longitude', 'akhir lon',
                'longitude akhir', 'lon akhir',
                'longitude 2', 'lon 2'
            ]
    
    # If we're looking for start coordinates, and just a single coordinate exists (no start/end distinction)
    if prefix == 'start' and column_type == 'lat':
        # Add cases where latitude exists without start/end specifier
        patterns.extend(['latitude', 'lat'])
    elif prefix == 'start' and column_type == 'lon':
        # Add cases where longitude exists without start/end specifier
        patterns.extend(['longitude', 'lon'])
    
    # Search for column containing any of the patterns
    for pattern in patterns:
        for col in df.columns:
            if isinstance(col, str) and pattern in col.lower():
                return col
    
    return None

def flatten_excel_to_geojson(file_path, output_folder, images_folder):
    """Convert all sheets from an Excel file to GeoJSON with image paths."""
    file_name = os.path.basename(file_path)
    file_basename_no_ext = os.path.splitext(file_name)[0]
    
    # Load workbook
    wb = load_workbook(file_path, data_only=True)
    
    # Keep track of which rows were kept for each sheet
    row_mapping = {}

    for sheet_name in wb.sheetnames:
        sheet_row_mapping = {}  # Store mapping from final index to original Excel row
        
        ws = wb[sheet_name]
        
        # Print sheet dimensions for debugging
        print(f"Processing sheet: {sheet_name} (Rows: {ws.max_row}, Columns: {ws.max_column})")

        # Unmerge cells and fill values
        for merge in list(ws.merged_cells):
            ws.unmerge_cells(str(merge))
            top_left = ws.cell(merge.min_row, merge.min_col).value
            for row in range(merge.min_row, merge.max_row + 1):
                for col in range(merge.min_col, merge.max_col + 1):
                    ws.cell(row, col, top_left)

        # Convert to DataFrame
        data = list(ws.values)
        df = pd.DataFrame(data)

        # Check if DataFrame is empty or has too few rows
        if df.empty or len(df) < 3:
            print(f"⚠️ Skipping '{sheet_name}' (Empty sheet or insufficient data)")
            continue

        # Find rows containing "NO" (safer approach)
        try:
            header_indices = df[df.apply(lambda x: x.astype(str).str.contains("NO", case=False, na=False)).any(axis=1)].index
            if len(header_indices) == 0:
                print(f"⚠️ Skipping '{sheet_name}' (No header row with 'NO' found)")
                continue
            header_index = header_indices[0]
        except Exception as e:
            print(f"⚠️ Skipping '{sheet_name}' (Error finding header row: {str(e)})")
            continue

        # Use the identified header row
        df.columns = df.iloc[header_index].astype(str).str.strip()

        # Remove empty columns
        df = df.dropna(axis=1, how="all")

        # First pass of REKAP filtering
        try:
            rekap_mask = df.columns.astype(str).str.contains("REKAP", case=False, na=False)
            if rekap_mask.any():
                df = df.loc[:, ~rekap_mask]
        except Exception as e:
            print(f"Warning in '{sheet_name}': Error filtering REKAP columns - {str(e)}")

        # Drop rows above and including header, plus the empty row after header
        rows_to_drop = list(range(0, header_index + 2))
        if len(df) > max(rows_to_drop) + 1:
            # Track which rows were kept and their original Excel row numbers
            kept_rows = [i for i in range(len(df)) if i not in rows_to_drop]
            for new_idx, old_idx in enumerate(kept_rows):
                # Original Excel row number is old_idx + 1 (since Excel is 1-indexed)
                sheet_row_mapping[new_idx] = old_idx + 1
                
            df = df.drop(index=rows_to_drop).reset_index(drop=True)
        else:
            print(f"⚠️ Skipping '{sheet_name}' (Not enough data rows after header)")
            continue

        # Improved header row merging
        if len(df) >= 2:
            # Convert values to strings
            first_row = df.iloc[0].astype(str).replace('None', '').replace('nan', '')
            second_row = df.iloc[1].astype(str).replace('None', '').replace('nan', '')
            
            # Smart merging
            merged_header = []
            for a, b in zip(first_row, second_row):
                a = a.strip()
                b = b.strip()
                
                if "rekap" in a.lower() or "rekap" in b.lower():
                    merged_header.append("TO_BE_REMOVED")
                    continue
                
                if not a and not b:
                    merged_header.append("Column_" + str(len(merged_header)))
                elif not a:
                    merged_header.append(b)
                elif not b:
                    merged_header.append(a)
                else:
                    if a.lower() in b.lower():
                        merged_header.append(b)
                    elif b.lower() in a.lower():
                        merged_header.append(a)
                    else:
                        merged_header.append(f"{a} {b}")
            
            # Ensure column names are unique
            df.columns = unique_column_names(merged_header)
            
            # Remove columns marked for removal
            df = df.loc[:, ~df.columns.str.contains("TO_BE_REMOVED")]
            
            # Update row mapping to account for removed header rows
            new_sheet_row_mapping = {}
            for new_idx, old_idx in enumerate(range(2, len(df))):
                if old_idx in sheet_row_mapping:
                    new_sheet_row_mapping[new_idx] = sheet_row_mapping[old_idx]
            sheet_row_mapping = new_sheet_row_mapping
            
            # Remove the first two rows used for headers
            df = df.drop(index=[0, 1]).reset_index(drop=True)
        else:
            print(f"⚠️ Skipping '{sheet_name}' (Not enough rows for headers)")
            continue

        # Store the final row mapping for this sheet
        row_mapping[sheet_name] = sheet_row_mapping
        
        # Print the row mapping for debugging
        print(f"Row mapping for sheet {sheet_name}:")
        for new_idx, excel_row in sheet_row_mapping.items():
            print(f"  GeoJSON idx {new_idx} -> Excel row {excel_row}")

        # Second pass of REKAP filtering
        try:
            rekap_mask = df.columns.astype(str).str.contains("REKAP", case=False, na=False)
            if rekap_mask.any():
                df = df.loc[:, ~rekap_mask]
        except Exception as e:
            print(f"Warning in '{sheet_name}': Error filtering REKAP columns (second pass) - {str(e)}")

        # Normalize column names
        df.columns = [str(col).lower().strip() if col is not None else f"col_{i}" 
                      for i, col in enumerate(df.columns)]
        
        # Third pass of REKAP filtering
        try:
            rekap_mask = df.columns.str.contains("rekap", case=False, na=False)
            if rekap_mask.any():
                df = df.loc[:, ~rekap_mask]
        except Exception as e:
            print(f"Warning in '{sheet_name}': Error filtering REKAP columns (third pass) - {str(e)}")

        # Find coordinate columns
        start_lat_col = find_coordinate_columns(df, 'start', 'lat')
        start_lon_col = find_coordinate_columns(df, 'start', 'lon')
        end_lat_col = find_coordinate_columns(df, 'end', 'lat')
        end_lon_col = find_coordinate_columns(df, 'end', 'lon')
        
        # Check if lat/lon columns found
        if not start_lat_col or not start_lon_col:
            print(f"⚠️ Skipping '{sheet_name}' (No latitude/longitude columns found)")
            continue
        
        # Fix coordinates
        df[[start_lat_col, start_lon_col]] = df.apply(
            lambda row: fix_coordinates(row, start_lat_col, start_lon_col), axis=1
        )
        
        if end_lat_col and end_lon_col:
            df[[end_lat_col, end_lon_col]] = df.apply(
                lambda row: fix_coordinates(row, end_lat_col, end_lon_col), axis=1
            )
        
        # Drop rows with invalid coordinates and update row mapping
        valid_rows = df.dropna(subset=[start_lat_col, start_lon_col]).index
        updated_mapping = {new_idx: sheet_row_mapping[old_idx] for new_idx, old_idx in enumerate(valid_rows) if old_idx in sheet_row_mapping}
        sheet_row_mapping = updated_mapping
        df = df.dropna(subset=[start_lat_col, start_lon_col]).reset_index(drop=True)
        
        if df.empty:
            print(f"⚠️ Skipping '{sheet_name}' (No valid coordinates found)")
            continue
        
        # Add original Excel row numbers to the dataframe for debugging
        df['original_excel_row'] = df.index.map(lambda idx: sheet_row_mapping.get(idx, 'unknown'))
        
        # Update row mapping for the sheet
        row_mapping[sheet_name] = sheet_row_mapping
        
        # Add image paths to dataframe
        df['image_paths'] = df.index.map(lambda idx: [])
        
        # Create GeoDataFrame
        geometry = []
        for idx, row in df.iterrows():
            try:
                start_lat = row[start_lat_col]
                start_lon = row[start_lon_col]
                
                # Create start point
                start_point = Point(start_lon, start_lat)
                
                # If we have end coordinates, create a LineString
                if end_lat_col and end_lon_col and pd.notna(row[end_lat_col]) and pd.notna(row[end_lon_col]):
                    end_lat = row[end_lat_col]
                    end_lon = row[end_lon_col]
                    geometry.append(LineString([(start_lon, start_lat), (end_lon, end_lat)]))
                else:
                    # Otherwise, just use the start point
                    geometry.append(start_point)
            except Exception as e:
                print(f"Error creating geometry for row {idx}: {str(e)}")
                # Add a placeholder point to maintain alignment
                geometry.append(Point(0, 0))
        
        # Create GeoDataFrame
        gdf = gpd.GeoDataFrame(df, geometry=geometry, crs="EPSG:4326")
        
        # Add Dokumentasi image paths using the correct row mapping
        file_basename = os.path.basename(file_path)
        file_basename_no_ext = os.path.splitext(file_basename)[0]
        
        # Now when we look for images, we'll use the original Excel row numbers
        gdf['Dokumentasi_Image_Paths'] = gdf.index.map(
            lambda idx: find_images_for_row(idx, sheet_row_mapping.get(idx, None), images_folder, 
                                           file_basename, file_basename_no_ext, sheet_name)
        )
        
        # Clean up columns
        gdf.columns = clean_column_names(gdf.columns)
        
        # Check if we have any valid geometries
        if len(gdf) == 0:
            print(f"⚠️ Skipping '{sheet_name}' (No valid geometries created)")
            continue
        
        # Save GeoJSON
        safe_sheet_name = re.sub(r'[\\/*?:"<>|]', "_", sheet_name)
        safe_file_name = re.sub(r'[\\/*?:"<>|]', "_", os.path.splitext(os.path.basename(file_path))[0])
        output_file = os.path.join(output_folder, f"{safe_file_name}_{safe_sheet_name}.geojson")
        
        # Save as GeoJSON
        clean_geojson(gdf, output_file)
        
    print(f"✅ Completed processing file: {os.path.basename(file_path)}")
    wb.close()
    return True

def find_images_for_row(idx, excel_row, images_folder, file_basename, file_basename_no_ext, sheet_name):
    """
    Find images for a specific row using the original Excel row number.
    """
    paths = []
    
    # If we have a valid Excel row number from our mapping
    if excel_row:
        # First check the image registry
        if file_basename in image_paths_registry and sheet_name in image_paths_registry[file_basename]:
            sheet_image_paths = image_paths_registry[file_basename][sheet_name]
            
            # The key insight: use the original Excel row number to look up images
            if excel_row in sheet_image_paths:
                for img_info in sheet_image_paths[excel_row]:
                    if img_info['category'].lower() == 'dokumentasi':
                        original_path = img_info['path']
                        filename = os.path.basename(original_path)
                        relative_path = f"../Extract Images/{file_basename_no_ext}/Dokumentasi/{filename}"
                        paths.append(relative_path)
                        print(f"Found match: GeoJSON idx {idx} -> Excel row {excel_row} -> {filename}")
    
    # If no images found through the registry, use the file system approach
    if not paths:
        dokumentasi_dir = os.path.join(images_folder, file_basename_no_ext, "Dokumentasi")
        if os.path.exists(dokumentasi_dir):
            # Search for files matching the Excel row number
            if excel_row:
                row_patterns = [f"Row{excel_row}", f"row{excel_row}", f"_Row{excel_row}", f"_row{excel_row}"]
                
                for filename in os.listdir(dokumentasi_dir):
                    for pattern in row_patterns:
                        if pattern in filename:
                            relative_path = f"../Extract Images/{file_basename_no_ext}/Dokumentasi/{filename}"
                            if relative_path not in paths:  # Avoid duplicates
                                paths.append(relative_path)
                                print(f"Found file match: GeoJSON idx {idx} -> Excel row {excel_row} -> {filename}")
    
    return paths

def main():
    """Main function to process Excel files with automatic folder structure."""
    print("Excel to GeoJSON with Image Extraction Utility")
    print("=============================================")
    
    # Get input folder from user
    input_folder = input("Enter the path to the folder containing Excel files: ").strip()
    
    # Validate input folder
    if not os.path.isdir(input_folder):
        print(f"❌ Error: The specified input folder '{input_folder}' does not exist.")
        return
    
    # Create main output folder structure automatically
    output_base_folder = os.path.join(os.path.dirname(input_folder), "Conversion Result")
    images_folder = os.path.join(output_base_folder, "Extract Images")
    geojson_folder = os.path.join(output_base_folder, "Convert GeoJSON")
    
    # Create output folders if they don't exist
    try:
        os.makedirs(output_base_folder, exist_ok=True)
        os.makedirs(images_folder, exist_ok=True)
        os.makedirs(geojson_folder, exist_ok=True)
        print(f"✅ Created output folder structure in: {output_base_folder}")
    except Exception as e:
        print(f"❌ Error: Could not create output folders: {str(e)}")
        return
    
    # Find all Excel files in input folder
    excel_files = glob.glob(os.path.join(input_folder, "*.xlsx"))
    
    if not excel_files:
        print("❌ No Excel files found in the input folder.")
        print(f"Please place Excel files in: {input_folder}")
        return
    
    print(f"Found {len(excel_files)} Excel files to process.")
    
    # Process each Excel file
    for i, file_path in enumerate(excel_files, 1):
        print(f"\n[{i}/{len(excel_files)}] Processing file: {os.path.basename(file_path)}")
        
        # Step 1: Extract images from Excel to the images folder directly
        print("\n=== STEP 1: Extracting images from Excel ===")
        # Change this line to use images_folder directly instead of file_images_folder
        images_extracted = extract_images_from_excel(file_path, images_folder)
        
        if not images_extracted:
            print(f"❌ Failed to extract images from {os.path.basename(file_path)}")
            continue
        
        # Step 2: Convert Excel to GeoJSON with image paths and save to GeoJSON folder
        print("\n=== STEP 2: Converting Excel to GeoJSON with image paths ===")
        geojson_converted = flatten_excel_to_geojson(file_path, geojson_folder, images_folder)
        
        if not geojson_converted:
            print(f"❌ Failed to convert {os.path.basename(file_path)} to GeoJSON")
            continue
        
        print(f"✅ Successfully processed {os.path.basename(file_path)}")
    
    print("\n=== PROCESSING COMPLETE ===")
    print(f"Images are in: {images_folder}")
    print(f"GeoJSON files are in: {geojson_folder}")

if __name__ == "__main__":
    main()
# Out:
# Some required packages are missing or need to be updated.
# Missing: openpyxl_image_loader
# Need update: None
# Installing missing packages: openpyxl_image_loader
# All required packages have been installed/updated successfully!
# Excel to GeoJSON with Image Extraction Utility
# =============================================
# ✅ Created output folder structure in: C:\Users\kanzi\Documents\Part Time Job\Conversion Result
# Found 2 Excel files to process.
#
# [1/2] Processing file: 01. Cileungsi - Cibeet.xlsx
#
# === STEP 1: Extracting images from Excel ===
# c:\Users\kanzi\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
# Processing sheet 1/13: RAMBU
# Found 'Nama Rambu' column: NAMA RAMBU (Column F)
# Found 172 images in DOKUMENTASI columns
# Processing 172 images in column 'DOKUMENTASI'
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row6.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row7.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row8.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row9.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row10.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row11.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row12.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row13.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row14.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row15.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row16.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row17.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row18.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row19.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row20.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row21.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row22.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row23.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row24.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row25.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row26.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row27.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row28.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row29.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row30.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row31.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row32.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row33.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row34.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row35.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row36.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row37.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row38.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row39.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row40.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row41.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row42.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row43.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row44.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row45.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row46.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row47.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row48.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row49.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row50.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row51.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row52.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row53.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row54.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row55.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row56.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row57.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row58.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row59.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row60.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row61.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row62.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row63.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row64.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row65.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row66.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row67.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row68.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row69.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row70.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row71.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row72.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row73.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row74.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row75.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row76.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row77.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row78.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row79.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row80.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row81.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row82.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row83.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row84.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row85.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row86.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row87.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row88.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row89.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row90.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row91.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row92.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row93.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row94.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row95.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row96.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row97.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row98.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row99.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row100.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row101.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row102.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row103.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row104.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row105.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row106.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row107.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row108.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row109.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row110.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row111.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row112.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row113.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row114.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row115.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row116.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row117.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row118.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row119.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row120.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row121.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row122.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row123.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row124.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row125.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row126.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row127.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row128.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row129.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row130.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row131.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row132.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row133.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row134.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row135.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row136.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row137.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row138.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row139.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row140.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row141.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row142.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row143.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row144.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row145.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row146.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row147.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row148.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row149.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row150.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row151.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row152.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row153.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row154.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row155.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row156.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row157.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row158.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row159.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row160.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row161.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row162.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row163.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row164.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row165.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row166.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row167.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row168.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row169.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row170.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row171.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row172.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row173.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row174.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row175.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row176.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_RAMBU_Column_DOKUMENTASI_Row177.png
# Found 171 images in RAMBU columns
# Processing 171 images in column 'GAMBAR RAMBU'
#   ✅ Saved: Larangan Berhneti.png
#   ⚠️ Duplicate 'Nama Rambu' found: Larangan Berhneti - Replacing existing image
#   ✅ Saved: Larangan Berhneti.png
#   ✅ Saved: Peringatan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Larangan Berhneti - Replacing existing image
#   ✅ Saved: Larangan Berhneti.png
#   ⚠️ Duplicate 'Nama Rambu' found: Larangan Berhneti - Replacing existing image
#   ✅ Saved: Larangan Berhneti.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan - Replacing existing image
#   ✅ Saved: Peringatan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan - Replacing existing image
#   ✅ Saved: Peringatan.png
#   ✅ Saved: Peringatan Banyak Lalu Lintas Pejalan Kaki.png
#   ✅ Saved: Peringatan Banayak Lalu Lintas Pejalan Kaki Anak-anak.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan - Replacing existing image
#   ✅ Saved: Peringatan.png
#   ✅ Saved: Petunjuk Lokasi SPBU.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan - Replacing existing image
#   ✅ Saved: Peringatan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan - Replacing existing image
#   ✅ Saved: Peringatan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Larangan Berhneti - Replacing existing image
#   ✅ Saved: Larangan Berhneti.png
#   ✅ Saved: Larangan Menyalip Kendaraan Lain.png
#   ✅ Saved: Peringatan Persimpanagan Tiga Sisi Kanan (ditempatkan pada lengan minor).png
#   ✅ Saved: Peringatan Banyak Lalu Linats Pejalan Kaki Menggunakan Fasilitas Penyebrangan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Larangan Berhneti - Replacing existing image
#   ✅ Saved: Larangan Berhneti.png
#   ⚠️ Duplicate 'Nama Rambu' found: Larangan Berhneti - Replacing existing image
#   ✅ Saved: Larangan Berhneti.png
#   ⚠️ Duplicate 'Nama Rambu' found: Larangan Berhneti - Replacing existing image
#   ✅ Saved: Larangan Berhneti.png
#   ✅ Saved: Petunjuk Lokasi Fasilitas Penyebrangan Pejalan Kaki.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Persimpanagan Tiga Sisi Kanan (ditempatkan pada lengan minor) - Replacing existing image
#   ✅ Saved: Peringatan Persimpanagan Tiga Sisi Kanan (ditempatkan pada lengan minor).png
#   ⚠️ Duplicate 'Nama Rambu' found: Larangan Menyalip Kendaraan Lain - Replacing existing image
#   ✅ Saved: Larangan Menyalip Kendaraan Lain.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan - Replacing existing image
#   ✅ Saved: Peringatan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Larangan Berhneti - Replacing existing image
#   ✅ Saved: Larangan Berhneti.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Banayak Lalu Lintas Pejalan Kaki Anak-anak - Replacing existing image
#   ✅ Saved: Peringatan Banayak Lalu Lintas Pejalan Kaki Anak-anak.png
#   ✅ Saved: Peringatan Tikungan ke Kanan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan - Replacing existing image
#   ✅ Saved: Peringatan.png
#   ✅ Saved: Peringatan Turunan Landai.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Banyak Lalu Linats Pejalan Kaki Menggunakan Fasilitas Penyebrangan - Replacing existing image
#   ✅ Saved: Peringatan Banyak Lalu Linats Pejalan Kaki Menggunakan Fasilitas Penyebrangan.png
#   ✅ Saved: Larangan Parkir.png
#   ⚠️ Duplicate 'Nama Rambu' found: Larangan Parkir - Replacing existing image
#   ✅ Saved: Larangan Parkir.png
#   ⚠️ Duplicate 'Nama Rambu' found: Petunjuk Lokasi Fasilitas Penyebrangan Pejalan Kaki - Replacing existing image
#   ✅ Saved: Petunjuk Lokasi Fasilitas Penyebrangan Pejalan Kaki.png
#   ⚠️ Duplicate 'Nama Rambu' found: Larangan Parkir - Replacing existing image
#   ✅ Saved: Larangan Parkir.png
#   ⚠️ Duplicate 'Nama Rambu' found: Larangan Parkir - Replacing existing image
#   ✅ Saved: Larangan Parkir.png
#   ⚠️ Duplicate 'Nama Rambu' found: Larangan Parkir - Replacing existing image
#   ✅ Saved: Larangan Parkir.png
#   ✅ Saved: Rambu Peringatan dengan Kata-kata.png
#   ⚠️ Duplicate 'Nama Rambu' found: Larangan Parkir - Replacing existing image
#   ✅ Saved: Larangan Parkir.png
#   ⚠️ Duplicate 'Nama Rambu' found: Larangan Parkir - Replacing existing image
#   ✅ Saved: Larangan Parkir.png
#   ✅ Saved: Peringatan Jalan Bergelombang.png
#   ⚠️ Duplicate 'Nama Rambu' found: Rambu Peringatan dengan Kata-kata - Replacing existing image
#   ✅ Saved: Rambu Peringatan dengan Kata-kata.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan - Replacing existing image
#   ✅ Saved: Peringatan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan ke Kanan - Replacing existing image
#   ✅ Saved: Peringatan Tikungan ke Kanan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Petunjuk Lokasi Fasilitas Penyebrangan Pejalan Kaki - Replacing existing image
#   ✅ Saved: Petunjuk Lokasi Fasilitas Penyebrangan Pejalan Kaki.png
#   ✅ Saved: Peringatan Tikungan ke Kiri.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Banyak Lalu Lintas Pejalan Kaki - Replacing existing image
#   ✅ Saved: Peringatan Banyak Lalu Lintas Pejalan Kaki.png
#   ✅ Saved: Petunjuk Lokasi Fasilitas Penyeberangan Pejalan Kaki.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan - Replacing existing image
#   ✅ Saved: Peringatan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Persimpanagan Tiga Sisi Kanan (ditempatkan pada lengan minor) - Replacing existing image
#   ✅ Saved: Peringatan Persimpanagan Tiga Sisi Kanan (ditempatkan pada lengan minor).png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan ke Kiri - Replacing existing image
#   ✅ Saved: Peringatan Tikungan ke Kiri.png
#   ✅ Saved: Peringatan Tikungan Tajam ke Kiri.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan ke Kiri - Replacing existing image
#   ✅ Saved: Peringatan Tikungan ke Kiri.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan ke Kiri - Replacing existing image
#   ✅ Saved: Peringatan Tikungan ke Kiri.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Banyak Lalu Linats Pejalan Kaki Menggunakan Fasilitas Penyebrangan - Replacing existing image
#   ✅ Saved: Peringatan Banyak Lalu Linats Pejalan Kaki Menggunakan Fasilitas Penyebrangan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan ke Kiri - Replacing existing image
#   ✅ Saved: Peringatan Tikungan ke Kiri.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan - Replacing existing image
#   ✅ Saved: Peringatan.png
#   ✅ Saved: Petunjuk Lokasi Masjid.png
#   ✅ Saved: Peringatan Jembatan Perinagatan Penyempitan Bagan Jalinan Jalan Tertentu.png
#   ✅ Saved: Peringatan Banyak Lalu Linats Pejalan Kaki Anak-anak.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Jembatan Perinagatan Penyempitan Bagan Jalinan Jalan Tertentu - Replacing existing image
#   ✅ Saved: Peringatan Jembatan Perinagatan Penyempitan Bagan Jalinan Jalan Tertentu.png
#   ⚠️ Duplicate 'Nama Rambu' found: Petunjuk Lokasi SPBU - Replacing existing image
#   ✅ Saved: Petunjuk Lokasi SPBU.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Banyak Lalu Linats Pejalan Kaki Anak-anak - Replacing existing image
#   ✅ Saved: Peringatan Banyak Lalu Linats Pejalan Kaki Anak-anak.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan - Replacing existing image
#   ✅ Saved: Peringatan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan ke Kiri - Replacing existing image
#   ✅ Saved: Peringatan Tikungan ke Kiri.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan ke Kanan - Replacing existing image
#   ✅ Saved: Peringatan Tikungan ke Kanan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Petunjuk Lokasi Fasilitas Penyeberangan Pejalan Kaki - Replacing existing image
#   ✅ Saved: Petunjuk Lokasi Fasilitas Penyeberangan Pejalan Kaki.png
#   ⚠️ Duplicate 'Nama Rambu' found: Petunjuk Lokasi Fasilitas Penyeberangan Pejalan Kaki - Replacing existing image
#   ✅ Saved: Petunjuk Lokasi Fasilitas Penyeberangan Pejalan Kaki.png
#   ⚠️ Duplicate 'Nama Rambu' found: Petunjuk Lokasi Fasilitas Penyeberangan Pejalan Kaki - Replacing existing image
#   ✅ Saved: Petunjuk Lokasi Fasilitas Penyeberangan Pejalan Kaki.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan ke Kanan - Replacing existing image
#   ✅ Saved: Peringatan Tikungan ke Kanan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan ke Kiri - Replacing existing image
#   ✅ Saved: Peringatan Tikungan ke Kiri.png
#   ✅ Saved: Peringatan Tanjakan Curam.png
#   ✅ Saved: Peringatan Persimpangan Tiga Sisi Kiri (Ditempatkan pada Lengan Minor.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan - Replacing existing image
#   ✅ Saved: Peringatan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan ke Kiri - Replacing existing image
#   ✅ Saved: Peringatan Tikungan ke Kiri.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan - Replacing existing image
#   ✅ Saved: Peringatan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Banyak Lalu Lintas Pejalan Kaki - Replacing existing image
#   ✅ Saved: Peringatan Banyak Lalu Lintas Pejalan Kaki.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan - Replacing existing image
#   ✅ Saved: Peringatan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan ke Kiri - Replacing existing image
#   ✅ Saved: Peringatan Tikungan ke Kiri.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan ke Kanan - Replacing existing image
#   ✅ Saved: Peringatan Tikungan ke Kanan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan - Replacing existing image
#   ✅ Saved: Peringatan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Petunjuk Lokasi Fasilitas Penyeberangan Pejalan Kaki - Replacing existing image
#   ✅ Saved: Petunjuk Lokasi Fasilitas Penyeberangan Pejalan Kaki.png
#   ⚠️ Duplicate 'Nama Rambu' found: Larangan Berhneti - Replacing existing image
#   ✅ Saved: Larangan Berhneti.png
#   ⚠️ Duplicate 'Nama Rambu' found: Petunjuk Lokasi Fasilitas Penyeberangan Pejalan Kaki - Replacing existing image
#   ✅ Saved: Petunjuk Lokasi Fasilitas Penyeberangan Pejalan Kaki.png
#   ✅ Saved: Perintah Mengikuti ke Arah Kanan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Banyak Lalu Linats Pejalan Kaki Anak-anak - Replacing existing image
#   ✅ Saved: Peringatan Banyak Lalu Linats Pejalan Kaki Anak-anak.png
#   ⚠️ Duplicate 'Nama Rambu' found: Petunjuk Lokasi Fasilitas Penyeberangan Pejalan Kaki - Replacing existing image
#   ✅ Saved: Petunjuk Lokasi Fasilitas Penyeberangan Pejalan Kaki.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan ke Kiri - Replacing existing image
#   ✅ Saved: Peringatan Tikungan ke Kiri.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan - Replacing existing image
#   ✅ Saved: Peringatan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Petunjuk Lokasi Masjid - Replacing existing image
#   ✅ Saved: Petunjuk Lokasi Masjid.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Banyak Lalu Lintas Pejalan Kaki - Replacing existing image
#   ✅ Saved: Peringatan Banyak Lalu Lintas Pejalan Kaki.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Banyak Lalu Linats Pejalan Kaki Anak-anak - Replacing existing image
#   ✅ Saved: Peringatan Banyak Lalu Linats Pejalan Kaki Anak-anak.png
#   ✅ Saved: Peringatan Turunan Curam.png
#   ⚠️ Duplicate 'Nama Rambu' found: Petunjuk Lokasi Masjid - Replacing existing image
#   ✅ Saved: Petunjuk Lokasi Masjid.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan - Replacing existing image
#   ✅ Saved: Peringatan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Jembatan Perinagatan Penyempitan Bagan Jalinan Jalan Tertentu - Replacing existing image
#   ✅ Saved: Peringatan Jembatan Perinagatan Penyempitan Bagan Jalinan Jalan Tertentu.png
#   ✅ Saved: Kecepatan Minimum yang Diperintahkan 40km_jam.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Banyak Lalu Linats Pejalan Kaki Anak-anak - Replacing existing image
#   ✅ Saved: Peringatan Banyak Lalu Linats Pejalan Kaki Anak-anak.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Banyak Lalu Lintas Pejalan Kaki - Replacing existing image
#   ✅ Saved: Peringatan Banyak Lalu Lintas Pejalan Kaki.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan - Replacing existing image
#   ✅ Saved: Peringatan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan ke Kanan - Replacing existing image
#   ✅ Saved: Peringatan Tikungan ke Kanan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan - Replacing existing image
#   ✅ Saved: Peringatan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Kecepatan Minimum yang Diperintahkan 40km_jam - Replacing existing image
#   ✅ Saved: Kecepatan Minimum yang Diperintahkan 40km_jam.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan - Replacing existing image
#   ✅ Saved: Peringatan.png
#   ✅ Saved: Perintah Memasuki Jalur atau lajur yang ditunjuk.png
#   ✅ Saved: Peringatan Banyak Tikungan dengan Tikungan Pertama Kiri.png
#   ✅ Saved: Peringatan Persimpangan Tiga Serong Kiri.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan ke Kanan - Replacing existing image
#   ✅ Saved: Peringatan Tikungan ke Kanan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan ke Kanan - Replacing existing image
#   ✅ Saved: Peringatan Tikungan ke Kanan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan ke Kanan - Replacing existing image
#   ✅ Saved: Peringatan Tikungan ke Kanan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan ke Kiri - Replacing existing image
#   ✅ Saved: Peringatan Tikungan ke Kiri.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan ke Kanan - Replacing existing image
#   ✅ Saved: Peringatan Tikungan ke Kanan.png
#   ✅ Saved: Peringatan Tikungan Tajam Ganda dengan Tikungan Pertama ke Kiri.png
#   ⚠️ Duplicate 'Nama Rambu' found: Larangan Berhneti - Replacing existing image
#   ✅ Saved: Larangan Berhneti.png
#   ⚠️ Duplicate 'Nama Rambu' found: Larangan Berhneti - Replacing existing image
#   ✅ Saved: Larangan Berhneti.png
#   ✅ Saved: Peringatan Permukaan Jalan yang Cembung Perinagatan Alat Pembatas Kecepatan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan - Replacing existing image
#   ✅ Saved: Peringatan.png
#   ✅ Saved: Peringatan Jembatan Peringatan Penyempitan Bagan Jalinan Jaln Tertentu.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan Tajam ke Kiri - Replacing existing image
#   ✅ Saved: Peringatan Tikungan Tajam ke Kiri.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan ke Kanan - Replacing existing image
#   ✅ Saved: Peringatan Tikungan ke Kanan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan ke Kiri - Replacing existing image
#   ✅ Saved: Peringatan Tikungan ke Kiri.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan - Replacing existing image
#   ✅ Saved: Peringatan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan ke Kiri - Replacing existing image
#   ✅ Saved: Peringatan Tikungan ke Kiri.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan - Replacing existing image
#   ✅ Saved: Peringatan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan ke Kiri - Replacing existing image
#   ✅ Saved: Peringatan Tikungan ke Kiri.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Turunan Landai - Replacing existing image
#   ✅ Saved: Peringatan Turunan Landai.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan ke Kanan - Replacing existing image
#   ✅ Saved: Peringatan Tikungan ke Kanan.png
#   ✅ Saved: Peringatan Tanjakan Landai.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Banyak Lalu Lintas Pejalan Kaki - Replacing existing image
#   ✅ Saved: Peringatan Banyak Lalu Lintas Pejalan Kaki.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Banyak Lalu Linats Pejalan Kaki Anak-anak - Replacing existing image
#   ✅ Saved: Peringatan Banyak Lalu Linats Pejalan Kaki Anak-anak.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Banyak Lalu Linats Pejalan Kaki Anak-anak - Replacing existing image
#   ✅ Saved: Peringatan Banyak Lalu Linats Pejalan Kaki Anak-anak.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tanjakan Curam - Replacing existing image
#   ✅ Saved: Peringatan Tanjakan Curam.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Turunan Landai - Replacing existing image
#   ✅ Saved: Peringatan Turunan Landai.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan ke Kanan - Replacing existing image
#   ✅ Saved: Peringatan Tikungan ke Kanan.png
#   ✅ Saved: Peringatan Banyak Tikungan dengan Tikungan Pertama Ke Kanan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Jembatan Peringatan Penyempitan Bagan Jalinan Jaln Tertentu - Replacing existing image
#   ✅ Saved: Peringatan Jembatan Peringatan Penyempitan Bagan Jalinan Jaln Tertentu.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan ke Kanan - Replacing existing image
#   ✅ Saved: Peringatan Tikungan ke Kanan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan ke Kiri - Replacing existing image
#   ✅ Saved: Peringatan Tikungan ke Kiri.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Banyak Lalu Linats Pejalan Kaki Anak-anak - Replacing existing image
#   ✅ Saved: Peringatan Banyak Lalu Linats Pejalan Kaki Anak-anak.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Turunan Landai - Replacing existing image
#   ✅ Saved: Peringatan Turunan Landai.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Turunan Landai - Replacing existing image
#   ✅ Saved: Peringatan Turunan Landai.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Turunan Landai - Replacing existing image
#   ✅ Saved: Peringatan Turunan Landai.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan ke Kanan - Replacing existing image
#   ✅ Saved: Peringatan Tikungan ke Kanan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tanjakan Landai - Replacing existing image
#   ✅ Saved: Peringatan Tanjakan Landai.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Banyak Lalu Linats Pejalan Kaki Anak-anak - Replacing existing image
#   ✅ Saved: Peringatan Banyak Lalu Linats Pejalan Kaki Anak-anak.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Banyak Lalu Linats Pejalan Kaki Anak-anak - Replacing existing image
#   ✅ Saved: Peringatan Banyak Lalu Linats Pejalan Kaki Anak-anak.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Banyak Lalu Linats Pejalan Kaki Anak-anak - Replacing existing image
#   ✅ Saved: Peringatan Banyak Lalu Linats Pejalan Kaki Anak-anak.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan ke Kiri - Replacing existing image
#   ✅ Saved: Peringatan Tikungan ke Kiri.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tanjakan Landai - Replacing existing image
#   ✅ Saved: Peringatan Tanjakan Landai.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan ke Kanan - Replacing existing image
#   ✅ Saved: Peringatan Tikungan ke Kanan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Turunan Landai - Replacing existing image
#   ✅ Saved: Peringatan Turunan Landai.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Turunan Landai - Replacing existing image
#   ✅ Saved: Peringatan Turunan Landai.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan ke Kiri - Replacing existing image
#   ✅ Saved: Peringatan Tikungan ke Kiri.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan ke Kanan - Replacing existing image
#   ✅ Saved: Peringatan Tikungan ke Kanan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Jembatan Peringatan Penyempitan Bagan Jalinan Jaln Tertentu - Replacing existing image
#   ✅ Saved: Peringatan Jembatan Peringatan Penyempitan Bagan Jalinan Jaln Tertentu.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Jembatan Peringatan Penyempitan Bagan Jalinan Jaln Tertentu - Replacing existing image
#   ✅ Saved: Peringatan Jembatan Peringatan Penyempitan Bagan Jalinan Jaln Tertentu.png
#   ✅ Saved: Peringatan Persimpangan Tiga Sisi Kiri (Ditempatkan pada Lengan Minor Kanan (Ditempatkan pada Lengan Mayor.png
#   ✅ Saved: Peringatan Persimpangan Tiga Sisi Kiri Ditempatkan pada Lengan Mayor).png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Jembatan Peringatan Penyempitan Bagan Jalinan Jaln Tertentu - Replacing existing image
#   ✅ Saved: Peringatan Jembatan Peringatan Penyempitan Bagan Jalinan Jaln Tertentu.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Banyak Lalu Linats Pejalan Kaki Anak-anak - Replacing existing image
#   ✅ Saved: Peringatan Banyak Lalu Linats Pejalan Kaki Anak-anak.png
#   ⚠️ Duplicate 'Nama Rambu' found: Petunjuk Lokasi Fasilitas Penyeberangan Pejalan Kaki - Replacing existing image
#   ✅ Saved: Petunjuk Lokasi Fasilitas Penyeberangan Pejalan Kaki.png
#   ⚠️ Duplicate 'Nama Rambu' found: Petunjuk Lokasi Fasilitas Penyeberangan Pejalan Kaki - Replacing existing image
#   ✅ Saved: Petunjuk Lokasi Fasilitas Penyeberangan Pejalan Kaki.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Banyak Lalu Linats Pejalan Kaki Anak-anak - Replacing existing image
#   ✅ Saved: Peringatan Banyak Lalu Linats Pejalan Kaki Anak-anak.png
#   ✅ Saved: Peringatan Tikungan Tajam ke Kanan.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan Tajam ke Kiri - Replacing existing image
#   ✅ Saved: Peringatan Tikungan Tajam ke Kiri.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Banyak Lalu Linats Pejalan Kaki Anak-anak - Replacing existing image
#   ✅ Saved: Peringatan Banyak Lalu Linats Pejalan Kaki Anak-anak.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tanjakan Landai - Replacing existing image
#   ✅ Saved: Peringatan Tanjakan Landai.png
#   ⚠️ Duplicate 'Nama Rambu' found: Petunjuk Lokasi Masjid - Replacing existing image
#   ✅ Saved: Petunjuk Lokasi Masjid.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Banyak Lalu Lintas Pejalan Kaki - Replacing existing image
#   ✅ Saved: Peringatan Banyak Lalu Lintas Pejalan Kaki.png
#   ⚠️ Duplicate 'Nama Rambu' found: Petunjuk Lokasi Masjid - Replacing existing image
#   ✅ Saved: Petunjuk Lokasi Masjid.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Banyak Lalu Lintas Pejalan Kaki - Replacing existing image
#   ✅ Saved: Peringatan Banyak Lalu Lintas Pejalan Kaki.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tikungan Tajam ke Kiri - Replacing existing image
#   ✅ Saved: Peringatan Tikungan Tajam ke Kiri.png
# ✅ Completed sheet 'RAMBU':
#   - Dokumentasi: 172 images
#   - Rambu: 171 images
#   - RPPJ: 0 images
# Processing sheet 2/13: PJU
# Found 'Jenis Tiang' column: JENIS TIANG Pilih Salah Satu (Column M)
# Found 469 images in DOKUMENTASI columns
# Processing 469 images in column 'DOKUMENTASI'
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row6.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row7.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row8.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row9.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row10.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row11.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row12.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row13.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row14.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row15.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row16.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row17.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row18.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row19.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row20.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row21.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row22.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row23.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row24.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row25.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row26.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row27.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row28.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row29.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row30.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row31.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row32.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row33.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row34.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row35.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row36.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row37.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row38.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row39.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row40.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row41.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row42.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row43.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row44.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row45.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row46.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row47.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row48.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row49.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row50.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row51.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row52.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row53.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row54.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row55.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row56.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row57.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row58.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row59.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row60.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row61.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row62.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row63.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row64.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row65.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row66.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row67.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row68.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row69.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row70.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row71.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row72.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row73.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row74.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row75.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row76.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row77.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row78.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row79.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row80.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row81.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row82.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row83.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row84.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row85.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row86.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row87.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row88.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row89.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row90.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row91.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row92.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row93.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row94.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row95.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row96.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row97.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row98.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row99.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row100.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row101.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row102.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row103.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row104.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row105.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row106.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row107.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row108.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row109.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row110.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row111.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row112.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row113.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row114.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row115.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row116.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row117.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row118.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row119.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row120.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row121.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row122.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row123.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row124.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row125.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row126.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row127.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row128.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row129.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row130.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row131.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row132.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row133.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row134.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row135.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row136.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row137.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row138.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row139.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row140.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row141.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row142.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row143.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row144.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row145.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row146.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row147.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row148.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row149.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row150.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row151.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row152.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row153.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row154.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row155.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row156.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row157.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row158.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row159.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row160.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row161.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row162.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row163.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row164.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row165.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row166.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row167.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row168.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row169.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row170.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row171.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row172.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row173.png
#   ✅ Saved: 01. Cileungsi - Cibeet_Sheet_PJU_Column_DOKUMENTASI_Row174.png
# ...
#   GeoJSON idx 562 -> Excel row 567
#   GeoJSON idx 563 -> Excel row 568
#   GeoJSON idx 564 -> Excel row 569
#   GeoJSON idx 565 -> Excel row 570
#   GeoJSON idx 566 -> Excel row 571
#   GeoJSON idx 567 -> Excel row 572
#   GeoJSON idx 568 -> Excel row 573
#   GeoJSON idx 569 -> Excel row 574
#   GeoJSON idx 570 -> Excel row 575
#   GeoJSON idx 571 -> Excel row 576
#   GeoJSON idx 572 -> Excel row 577
#   GeoJSON idx 573 -> Excel row 578
#   GeoJSON idx 574 -> Excel row 579
#   GeoJSON idx 575 -> Excel row 580
#   GeoJSON idx 576 -> Excel row 581
#   GeoJSON idx 577 -> Excel row 582
#   GeoJSON idx 578 -> Excel row 583
#   GeoJSON idx 579 -> Excel row 584
#   GeoJSON idx 580 -> Excel row 585
#   GeoJSON idx 581 -> Excel row 586
#   GeoJSON idx 582 -> Excel row 587
#   GeoJSON idx 583 -> Excel row 588
#   GeoJSON idx 584 -> Excel row 589
#   GeoJSON idx 585 -> Excel row 590
#   GeoJSON idx 586 -> Excel row 591
#   GeoJSON idx 587 -> Excel row 592
#   GeoJSON idx 588 -> Excel row 593
#   GeoJSON idx 589 -> Excel row 594
#   GeoJSON idx 590 -> Excel row 595
#   GeoJSON idx 591 -> Excel row 596
#   GeoJSON idx 592 -> Excel row 597
#   GeoJSON idx 593 -> Excel row 598
#   GeoJSON idx 594 -> Excel row 599
#   GeoJSON idx 595 -> Excel row 600
#   GeoJSON idx 596 -> Excel row 601
#   GeoJSON idx 597 -> Excel row 602
#   GeoJSON idx 598 -> Excel row 603
#   GeoJSON idx 599 -> Excel row 604
#   GeoJSON idx 600 -> Excel row 605
#   GeoJSON idx 601 -> Excel row 606
#   GeoJSON idx 602 -> Excel row 607
#   GeoJSON idx 603 -> Excel row 608
#   GeoJSON idx 604 -> Excel row 609
#   GeoJSON idx 605 -> Excel row 610
#   GeoJSON idx 606 -> Excel row 611
#   GeoJSON idx 607 -> Excel row 612
#   GeoJSON idx 608 -> Excel row 613
#   GeoJSON idx 609 -> Excel row 614
#   GeoJSON idx 610 -> Excel row 615
#   GeoJSON idx 611 -> Excel row 616
#   GeoJSON idx 612 -> Excel row 617
#   GeoJSON idx 613 -> Excel row 618
#   GeoJSON idx 614 -> Excel row 619
#   GeoJSON idx 615 -> Excel row 620
#   GeoJSON idx 616 -> Excel row 621
#   GeoJSON idx 617 -> Excel row 622
#   GeoJSON idx 618 -> Excel row 623
#   GeoJSON idx 619 -> Excel row 624
#   GeoJSON idx 620 -> Excel row 625
#   GeoJSON idx 621 -> Excel row 626
#   GeoJSON idx 622 -> Excel row 627
#   GeoJSON idx 623 -> Excel row 628
#   GeoJSON idx 624 -> Excel row 629
#   GeoJSON idx 625 -> Excel row 630
#   GeoJSON idx 626 -> Excel row 631
#   GeoJSON idx 627 -> Excel row 632
#   GeoJSON idx 628 -> Excel row 633
#   GeoJSON idx 629 -> Excel row 634
#   GeoJSON idx 630 -> Excel row 635
#   GeoJSON idx 631 -> Excel row 636
#   GeoJSON idx 632 -> Excel row 637
#   GeoJSON idx 633 -> Excel row 638
#   GeoJSON idx 634 -> Excel row 639
#   GeoJSON idx 635 -> Excel row 640
#   GeoJSON idx 636 -> Excel row 641
#   GeoJSON idx 637 -> Excel row 642
#   GeoJSON idx 638 -> Excel row 643
#   GeoJSON idx 639 -> Excel row 644
#   GeoJSON idx 640 -> Excel row 645
#   GeoJSON idx 641 -> Excel row 646
#   GeoJSON idx 642 -> Excel row 647
#   GeoJSON idx 643 -> Excel row 648
#   GeoJSON idx 644 -> Excel row 649
#   GeoJSON idx 645 -> Excel row 650
#   GeoJSON idx 646 -> Excel row 651
#   GeoJSON idx 647 -> Excel row 652
#   GeoJSON idx 648 -> Excel row 653
#   GeoJSON idx 649 -> Excel row 654
#   GeoJSON idx 650 -> Excel row 655
#   GeoJSON idx 651 -> Excel row 656
#   GeoJSON idx 652 -> Excel row 657
#   GeoJSON idx 653 -> Excel row 658
#   GeoJSON idx 654 -> Excel row 659
#   GeoJSON idx 655 -> Excel row 660
#   GeoJSON idx 656 -> Excel row 661
#   GeoJSON idx 657 -> Excel row 662
#   GeoJSON idx 658 -> Excel row 663
#   GeoJSON idx 659 -> Excel row 664
#   GeoJSON idx 660 -> Excel row 665
#   GeoJSON idx 661 -> Excel row 666
#   GeoJSON idx 662 -> Excel row 667
#   GeoJSON idx 663 -> Excel row 668
#   GeoJSON idx 664 -> Excel row 669
#   GeoJSON idx 665 -> Excel row 670
#   GeoJSON idx 666 -> Excel row 671
#   GeoJSON idx 667 -> Excel row 672
#   GeoJSON idx 668 -> Excel row 673
#   GeoJSON idx 669 -> Excel row 674
#   GeoJSON idx 670 -> Excel row 675
#   GeoJSON idx 671 -> Excel row 676
#   GeoJSON idx 672 -> Excel row 677
#   GeoJSON idx 673 -> Excel row 678
#   GeoJSON idx 674 -> Excel row 679
#   GeoJSON idx 675 -> Excel row 680
#   GeoJSON idx 676 -> Excel row 681
#   GeoJSON idx 677 -> Excel row 682
#   GeoJSON idx 678 -> Excel row 683
#   GeoJSON idx 679 -> Excel row 684
#   GeoJSON idx 680 -> Excel row 685
#   GeoJSON idx 681 -> Excel row 686
#   GeoJSON idx 682 -> Excel row 687
#   GeoJSON idx 683 -> Excel row 688
#   GeoJSON idx 684 -> Excel row 689
#   GeoJSON idx 685 -> Excel row 690
#   GeoJSON idx 686 -> Excel row 691
#   GeoJSON idx 687 -> Excel row 692
#   GeoJSON idx 688 -> Excel row 693
#   GeoJSON idx 689 -> Excel row 694
#   GeoJSON idx 690 -> Excel row 695
#   GeoJSON idx 691 -> Excel row 696
#   GeoJSON idx 692 -> Excel row 697
#   GeoJSON idx 693 -> Excel row 698
#   GeoJSON idx 694 -> Excel row 699
#   GeoJSON idx 695 -> Excel row 700
#   GeoJSON idx 696 -> Excel row 701
#   GeoJSON idx 697 -> Excel row 702
#   GeoJSON idx 698 -> Excel row 703
#   GeoJSON idx 699 -> Excel row 704
#   GeoJSON idx 700 -> Excel row 705
#   GeoJSON idx 701 -> Excel row 706
#   GeoJSON idx 702 -> Excel row 707
#   GeoJSON idx 703 -> Excel row 708
#   GeoJSON idx 704 -> Excel row 709
#   GeoJSON idx 705 -> Excel row 710
#   GeoJSON idx 706 -> Excel row 711
#   GeoJSON idx 707 -> Excel row 712
#   GeoJSON idx 708 -> Excel row 713
#   GeoJSON idx 709 -> Excel row 714
#   GeoJSON idx 710 -> Excel row 715
#   GeoJSON idx 711 -> Excel row 716
#   GeoJSON idx 712 -> Excel row 717
#   GeoJSON idx 713 -> Excel row 718
#   GeoJSON idx 714 -> Excel row 719
#   GeoJSON idx 715 -> Excel row 720
#   GeoJSON idx 716 -> Excel row 721
#   GeoJSON idx 717 -> Excel row 722
#   GeoJSON idx 718 -> Excel row 723
#   GeoJSON idx 719 -> Excel row 724
#   GeoJSON idx 720 -> Excel row 725
#   GeoJSON idx 721 -> Excel row 726
#   GeoJSON idx 722 -> Excel row 727
#   GeoJSON idx 723 -> Excel row 728
#   GeoJSON idx 724 -> Excel row 729
#   GeoJSON idx 725 -> Excel row 730
#   GeoJSON idx 726 -> Excel row 731
#   GeoJSON idx 727 -> Excel row 732
#   GeoJSON idx 728 -> Excel row 733
#   GeoJSON idx 729 -> Excel row 734
#   GeoJSON idx 730 -> Excel row 735
#   GeoJSON idx 731 -> Excel row 736
#   GeoJSON idx 732 -> Excel row 737
#   GeoJSON idx 733 -> Excel row 738
#   GeoJSON idx 734 -> Excel row 739
#   GeoJSON idx 735 -> Excel row 740
#   GeoJSON idx 736 -> Excel row 741
#   GeoJSON idx 737 -> Excel row 742
#   GeoJSON idx 738 -> Excel row 743
#   GeoJSON idx 739 -> Excel row 744
#   GeoJSON idx 740 -> Excel row 745
#   GeoJSON idx 741 -> Excel row 746
#   GeoJSON idx 742 -> Excel row 747
#   GeoJSON idx 743 -> Excel row 748
#   GeoJSON idx 744 -> Excel row 749
#   GeoJSON idx 745 -> Excel row 750
#   GeoJSON idx 746 -> Excel row 751
#   GeoJSON idx 747 -> Excel row 752
#   GeoJSON idx 748 -> Excel row 753
#   GeoJSON idx 749 -> Excel row 754
#   GeoJSON idx 750 -> Excel row 755
#   GeoJSON idx 751 -> Excel row 756
#   GeoJSON idx 752 -> Excel row 757
#   GeoJSON idx 753 -> Excel row 758
#   GeoJSON idx 754 -> Excel row 759
#   GeoJSON idx 755 -> Excel row 760
#   GeoJSON idx 756 -> Excel row 761
#   GeoJSON idx 757 -> Excel row 762
#   GeoJSON idx 758 -> Excel row 763
#   GeoJSON idx 759 -> Excel row 764
#   GeoJSON idx 760 -> Excel row 765
#   GeoJSON idx 761 -> Excel row 766
#   GeoJSON idx 762 -> Excel row 767
#   GeoJSON idx 763 -> Excel row 768
#   GeoJSON idx 764 -> Excel row 769
#   GeoJSON idx 765 -> Excel row 770
#   GeoJSON idx 766 -> Excel row 771
#   GeoJSON idx 767 -> Excel row 772
#   GeoJSON idx 768 -> Excel row 773
#   GeoJSON idx 769 -> Excel row 774
#   GeoJSON idx 770 -> Excel row 775
#   GeoJSON idx 771 -> Excel row 776
#   GeoJSON idx 772 -> Excel row 777
#   GeoJSON idx 773 -> Excel row 778
#   GeoJSON idx 774 -> Excel row 779
#   GeoJSON idx 775 -> Excel row 780
#   GeoJSON idx 776 -> Excel row 781
#   GeoJSON idx 777 -> Excel row 782
#   GeoJSON idx 778 -> Excel row 783
#   GeoJSON idx 779 -> Excel row 784
#   GeoJSON idx 780 -> Excel row 785
#   GeoJSON idx 781 -> Excel row 786
#   GeoJSON idx 782 -> Excel row 787
#   GeoJSON idx 783 -> Excel row 788
#   GeoJSON idx 784 -> Excel row 789
#   GeoJSON idx 785 -> Excel row 790
#   GeoJSON idx 786 -> Excel row 791
#   GeoJSON idx 787 -> Excel row 792
#   GeoJSON idx 788 -> Excel row 793
#   GeoJSON idx 789 -> Excel row 794
#   GeoJSON idx 790 -> Excel row 795
#   GeoJSON idx 791 -> Excel row 796
#   GeoJSON idx 792 -> Excel row 797
#   GeoJSON idx 793 -> Excel row 798
#   GeoJSON idx 794 -> Excel row 799
#   GeoJSON idx 795 -> Excel row 800
#   GeoJSON idx 796 -> Excel row 801
#   GeoJSON idx 797 -> Excel row 802
#   GeoJSON idx 798 -> Excel row 803
#   GeoJSON idx 799 -> Excel row 804
#   GeoJSON idx 800 -> Excel row 805
#   GeoJSON idx 801 -> Excel row 806
#   GeoJSON idx 802 -> Excel row 807
#   GeoJSON idx 803 -> Excel row 808
#   GeoJSON idx 804 -> Excel row 809
#   GeoJSON idx 805 -> Excel row 810
#   GeoJSON idx 806 -> Excel row 811
#   GeoJSON idx 807 -> Excel row 812
#   GeoJSON idx 808 -> Excel row 813
#   GeoJSON idx 809 -> Excel row 814
#   GeoJSON idx 810 -> Excel row 815
#   GeoJSON idx 811 -> Excel row 816
#   GeoJSON idx 812 -> Excel row 817
#   GeoJSON idx 813 -> Excel row 818
#   GeoJSON idx 814 -> Excel row 819
#   GeoJSON idx 815 -> Excel row 820
#   GeoJSON idx 816 -> Excel row 821
#   GeoJSON idx 817 -> Excel row 822
#   GeoJSON idx 818 -> Excel row 823
#   GeoJSON idx 819 -> Excel row 824
#   GeoJSON idx 820 -> Excel row 825
#   GeoJSON idx 821 -> Excel row 826
#   GeoJSON idx 822 -> Excel row 827
#   GeoJSON idx 823 -> Excel row 828
#   GeoJSON idx 824 -> Excel row 829
#   GeoJSON idx 825 -> Excel row 830
#   GeoJSON idx 826 -> Excel row 831
#   GeoJSON idx 827 -> Excel row 832
#   GeoJSON idx 828 -> Excel row 833
#   GeoJSON idx 829 -> Excel row 834
#   GeoJSON idx 830 -> Excel row 835
#   GeoJSON idx 831 -> Excel row 836
#   GeoJSON idx 832 -> Excel row 837
#   GeoJSON idx 833 -> Excel row 838
#   GeoJSON idx 834 -> Excel row 839
#   GeoJSON idx 835 -> Excel row 840
#   GeoJSON idx 836 -> Excel row 841
#   GeoJSON idx 837 -> Excel row 842
#   GeoJSON idx 838 -> Excel row 843
#   GeoJSON idx 839 -> Excel row 844
#   GeoJSON idx 840 -> Excel row 845
#   GeoJSON idx 841 -> Excel row 846
#   GeoJSON idx 842 -> Excel row 847
#   GeoJSON idx 843 -> Excel row 848
#   GeoJSON idx 844 -> Excel row 849
#   GeoJSON idx 845 -> Excel row 850
#   GeoJSON idx 846 -> Excel row 851
#   GeoJSON idx 847 -> Excel row 852
#   GeoJSON idx 848 -> Excel row 853
#   GeoJSON idx 849 -> Excel row 854
#   GeoJSON idx 850 -> Excel row 855
#   GeoJSON idx 851 -> Excel row 856
#   GeoJSON idx 852 -> Excel row 857
#   GeoJSON idx 853 -> Excel row 858
#   GeoJSON idx 854 -> Excel row 859
#   GeoJSON idx 855 -> Excel row 860
#   GeoJSON idx 856 -> Excel row 861
#   GeoJSON idx 857 -> Excel row 862
#   GeoJSON idx 858 -> Excel row 863
#   GeoJSON idx 859 -> Excel row 864
#   GeoJSON idx 860 -> Excel row 865
#   GeoJSON idx 861 -> Excel row 866
#   GeoJSON idx 862 -> Excel row 867
#   GeoJSON idx 863 -> Excel row 868
#   GeoJSON idx 864 -> Excel row 869
#   GeoJSON idx 865 -> Excel row 870
#   GeoJSON idx 866 -> Excel row 871
#   GeoJSON idx 867 -> Excel row 872
#   GeoJSON idx 868 -> Excel row 873
#   GeoJSON idx 869 -> Excel row 874
#   GeoJSON idx 870 -> Excel row 875
#   GeoJSON idx 871 -> Excel row 876
#   GeoJSON idx 872 -> Excel row 877
#   GeoJSON idx 873 -> Excel row 878
#   GeoJSON idx 874 -> Excel row 879
#   GeoJSON idx 875 -> Excel row 880
#   GeoJSON idx 876 -> Excel row 881
#   GeoJSON idx 877 -> Excel row 882
#   GeoJSON idx 878 -> Excel row 883
#   GeoJSON idx 879 -> Excel row 884
#   GeoJSON idx 880 -> Excel row 885
#   GeoJSON idx 881 -> Excel row 886
#   GeoJSON idx 882 -> Excel row 887
#   GeoJSON idx 883 -> Excel row 888
#   GeoJSON idx 884 -> Excel row 889
#   GeoJSON idx 885 -> Excel row 890
#   GeoJSON idx 886 -> Excel row 891
#   GeoJSON idx 887 -> Excel row 892
#   GeoJSON idx 888 -> Excel row 893
#   GeoJSON idx 889 -> Excel row 894
#   GeoJSON idx 890 -> Excel row 895
#   GeoJSON idx 891 -> Excel row 896
#   GeoJSON idx 892 -> Excel row 897
#   GeoJSON idx 893 -> Excel row 898
#   GeoJSON idx 894 -> Excel row 899
#   GeoJSON idx 895 -> Excel row 900
#   GeoJSON idx 896 -> Excel row 901
#   GeoJSON idx 897 -> Excel row 902
#   GeoJSON idx 898 -> Excel row 903
#   GeoJSON idx 899 -> Excel row 904
#   GeoJSON idx 900 -> Excel row 905
#   GeoJSON idx 901 -> Excel row 906
#   GeoJSON idx 902 -> Excel row 907
#   GeoJSON idx 903 -> Excel row 908
#   GeoJSON idx 904 -> Excel row 909
#   GeoJSON idx 905 -> Excel row 910
#   GeoJSON idx 906 -> Excel row 911
#   GeoJSON idx 907 -> Excel row 912
#   GeoJSON idx 908 -> Excel row 913
#   GeoJSON idx 909 -> Excel row 914
#   GeoJSON idx 910 -> Excel row 915
#   GeoJSON idx 911 -> Excel row 916
#   GeoJSON idx 912 -> Excel row 917
#   GeoJSON idx 913 -> Excel row 918
#   GeoJSON idx 914 -> Excel row 919
#   GeoJSON idx 915 -> Excel row 920
#   GeoJSON idx 916 -> Excel row 921
#   GeoJSON idx 917 -> Excel row 922
#   GeoJSON idx 918 -> Excel row 923
#   GeoJSON idx 919 -> Excel row 924
#   GeoJSON idx 920 -> Excel row 925
#   GeoJSON idx 921 -> Excel row 926
#   GeoJSON idx 922 -> Excel row 927
#   GeoJSON idx 923 -> Excel row 928
#   GeoJSON idx 924 -> Excel row 929
#   GeoJSON idx 925 -> Excel row 930
#   GeoJSON idx 926 -> Excel row 931
#   GeoJSON idx 927 -> Excel row 932
#   GeoJSON idx 928 -> Excel row 933
#   GeoJSON idx 929 -> Excel row 934
#   GeoJSON idx 930 -> Excel row 935
#   GeoJSON idx 931 -> Excel row 936
#   GeoJSON idx 932 -> Excel row 937
#   GeoJSON idx 933 -> Excel row 938
#   GeoJSON idx 934 -> Excel row 939
#   GeoJSON idx 935 -> Excel row 940
#   GeoJSON idx 936 -> Excel row 941
#   GeoJSON idx 937 -> Excel row 942
#   GeoJSON idx 938 -> Excel row 943
#   GeoJSON idx 939 -> Excel row 944
#   GeoJSON idx 940 -> Excel row 945
#   GeoJSON idx 941 -> Excel row 946
#   GeoJSON idx 942 -> Excel row 947
#   GeoJSON idx 943 -> Excel row 948
#   GeoJSON idx 944 -> Excel row 949
#   GeoJSON idx 945 -> Excel row 950
#   GeoJSON idx 946 -> Excel row 951
#   GeoJSON idx 947 -> Excel row 952
#   GeoJSON idx 948 -> Excel row 953
#   GeoJSON idx 949 -> Excel row 954
#   GeoJSON idx 950 -> Excel row 955
#   GeoJSON idx 951 -> Excel row 956
#   GeoJSON idx 952 -> Excel row 957
#   GeoJSON idx 953 -> Excel row 958
#   GeoJSON idx 954 -> Excel row 959
#   GeoJSON idx 955 -> Excel row 960
#   GeoJSON idx 956 -> Excel row 961
#   GeoJSON idx 957 -> Excel row 962
#   GeoJSON idx 958 -> Excel row 963
#   GeoJSON idx 959 -> Excel row 964
#   GeoJSON idx 960 -> Excel row 965
#   GeoJSON idx 961 -> Excel row 966
#   GeoJSON idx 962 -> Excel row 967
#   GeoJSON idx 963 -> Excel row 968
#   GeoJSON idx 964 -> Excel row 969
#   GeoJSON idx 965 -> Excel row 970
#   GeoJSON idx 966 -> Excel row 971
#   GeoJSON idx 967 -> Excel row 972
#   GeoJSON idx 968 -> Excel row 973
#   GeoJSON idx 969 -> Excel row 974
#   GeoJSON idx 970 -> Excel row 975
#   GeoJSON idx 971 -> Excel row 976
#   GeoJSON idx 972 -> Excel row 977
#   GeoJSON idx 973 -> Excel row 978
#   GeoJSON idx 974 -> Excel row 979
#   GeoJSON idx 975 -> Excel row 980
#   GeoJSON idx 976 -> Excel row 981
#   GeoJSON idx 977 -> Excel row 982
#   GeoJSON idx 978 -> Excel row 983
#   GeoJSON idx 979 -> Excel row 984
#   GeoJSON idx 980 -> Excel row 985
#   GeoJSON idx 981 -> Excel row 986
#   GeoJSON idx 982 -> Excel row 987
#   GeoJSON idx 983 -> Excel row 988
#   GeoJSON idx 984 -> Excel row 989
#   GeoJSON idx 985 -> Excel row 990
#   GeoJSON idx 986 -> Excel row 991
#   GeoJSON idx 987 -> Excel row 992
#   GeoJSON idx 988 -> Excel row 993
#   GeoJSON idx 989 -> Excel row 994
#   GeoJSON idx 990 -> Excel row 995
#   GeoJSON idx 991 -> Excel row 996
#   GeoJSON idx 992 -> Excel row 997
#   GeoJSON idx 993 -> Excel row 998
#   GeoJSON idx 994 -> Excel row 999
#   GeoJSON idx 995 -> Excel row 1000
# ⚠️ Skipping 'CERMIN TIKUNG' (No valid coordinates found)
# ✅ Completed processing file: 01. Cileungsi - Cibeet.xlsx
# ✅ Successfully processed 01. Cileungsi - Cibeet.xlsx
#
# [2/2] Processing file: ~$01. Cileungsi - Cibeet.xlsx
#
# === STEP 1: Extracting images from Excel ===
# ❌ Error processing file 'C:\Users\kanzi\Documents\Part Time Job\Data Hasil Survey\~$01. Cileungsi - Cibeet.xlsx': [Errno 13] Permission denied: 'C:\\Users\\kanzi\\Documents\\Part Time Job\\Data Hasil Survey\\~$01. Cileungsi - Cibeet.xlsx'
# ❌ Failed to extract images from ~$01. Cileungsi - Cibeet.xlsx
#
# === PROCESSING COMPLETE ===
# Images are in: C:\Users\kanzi\Documents\Part Time Job\Conversion Result\Extract Images
# GeoJSON files are in: C:\Users\kanzi\Documents\Part Time Job\Conversion Result\Convert GeoJSON
