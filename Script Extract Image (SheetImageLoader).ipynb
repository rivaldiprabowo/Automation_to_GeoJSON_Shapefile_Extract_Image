# %% [markdown]
# # Application to Extract Image from Excel

# %% [markdown]
# ## 1. Import Library

# %%
import os
import pandas as pd
from openpyxl_image_loader import SheetImageLoader
from openpyxl import load_workbook
from openpyxl.drawing.image import Image
from PIL import Image
import io
import re
import gc
from concurrent.futures import ThreadPoolExecutor
import time
from io import BytesIO
from openpyxl.utils import column_index_from_string, get_column_letter
from lxml import etree
import zipfile
import shutil
import xml.etree.ElementTree as ET
from PIL import Image as PILImage
from collections import defaultdict

# %% [markdown]
# ## 2. Application to Extract Images from Excel

# %% [markdown]
# ### 2.1. Function Codes

# %%
def unique_column_names(columns): #Ensure column names are unique by appending a suffix.
    seen = {}
    new_columns = []
    for col in columns:
        if col in seen:
            seen[col] += 1
            new_columns.append(f"{col}_{seen[col]}")
        else:
            seen[col] = 0
            new_columns.append(col)
    return new_columns

def clean_column_names(columns): #Standardize column names by capitalizing each word properly.
    cleaned_columns = []
    seen = {}
    for col in columns:
        col = str(col).strip()
        col = " ".join(word.capitalize() for word in col.split())
        if col in seen:
            seen[col] += 1
            col = f"{col} {seen[col]}"
        else:
            seen[col] = 0
        cleaned_columns.append(col)
    return cleaned_columns

def extract_images_from_excel(file_path, output_folder): #"Extract images from columns containing 'DOKUMENTASI' in all sheets and save them.
    
    try:
        # Extract filename from path
        file_name_clean = re.search(r'([^\\]+)\.xlsx$', file_path)
        if file_name_clean:
            file_name_clean = file_name_clean.group(1)
        else:
            file_name_clean = os.path.basename(file_path).replace('.xlsx', '')
        
        # Process each sheet independently to prevent file handle issues
        wb = load_workbook(file_path, data_only=True)
        sheet_names = wb.sheetnames.copy()  # Make a copy of sheet names before closing
        wb.close()  # Close immediately to avoid keeping file handles open
        
        successful_sheets = 0
        
        for sheet_name in sheet_names:
            try:
                print(f"Processing sheet: {sheet_name}")
                
                # Open a fresh workbook instance for each sheet
                wb = load_workbook(file_path, data_only=True)
                ws = wb[sheet_name]
                
                # Create a fresh image loader for this sheet
                image_loader = SheetImageLoader(ws)
                
                # Unmerge cells and fill values
                for merge in list(ws.merged_cells):
                    ws.unmerge_cells(str(merge))
                    top_left = ws.cell(merge.min_row, merge.min_col).value
                    for row in range(merge.min_row, merge.max_row + 1):
                        for col in range(merge.min_col, merge.max_col + 1):
                            ws.cell(row, col, top_left)
                
                # Convert to DataFrame
                data = list(ws.values)
                df = pd.DataFrame(data)
                
                # Identify the header row
                try:
                    header_index = df[df.apply(lambda x: x.astype(str).str.contains("NO", case=False, na=False)).any(axis=1)].index[0]
                except IndexError:
                    print(f"⚠️ Could not identify header row in sheet '{sheet_name}' of file '{file_name_clean}', skipping...")
                    wb.close()  # Close before continuing to next sheet
                    continue
                
                # Set the header
                df.columns = df.iloc[2].astype(str).str.strip()
                
                # Remove empty columns
                df = df.dropna(axis=1, how="all")
                
                # Drop "REKAP" section if present
                df = df.loc[:, ~df.columns.str.contains("REKAP", case=False, na=False)]
                df = df.drop(index=[0, 1, 4]).reset_index(drop=True)
                
                # Merge first two rows if needed
                merged_header = [a if a == b else f"{a} {b}" for a, b in zip(df.iloc[0], df.iloc[1])]
                
                # Ensure column names are unique
                df.columns = unique_column_names(merged_header)
                
                # Remove the first two rows used for headers
                df = df.drop(index=[0, 1]).reset_index(drop=True)
                
                # Normalize column names for consistent detection
                df.columns = df.columns.str.upper().str.strip()

                # Apply column renaming after creating the GeoDataFrame
                df.columns = clean_column_names(df.columns)

                # Remove unwanted "None_" and "None" columns
                df = df.loc[:, ~df.columns.str.match(r"^None$|None_", na=False)]

                # Remove " None" from remaining column names
                df.columns = df.columns.str.replace(r"\sNone\b", "", regex=True).str.strip()
                
                # Find all columns that contain "DOKUMENTASI" (case-insensitive)
                dokumentasi_cols = [col for col in df.columns if "DOKUMENTASI" in col.upper()]
                
                # Skip processing if no dokumentasi columns are found
                if not dokumentasi_cols:
                    print(f"⚠️ No 'DOKUMENTASI' columns found in sheet '{sheet_name}' of file '{file_name_clean}', skipping...")
                    wb.close()  # Close before continuing to next sheet
                    continue
                
                print(f"Found {len(dokumentasi_cols)} 'DOKUMENTASI' columns in sheet '{sheet_name}'")
                
                # First collect all cell coordinates with images
                image_cells = []
                for col_idx, col_name in enumerate(df.columns):
                    if col_name not in dokumentasi_cols:
                        continue
                    
                    # Calculate proper column index (Excel columns are 1-indexed)
                    excel_col_idx = col_idx + 1
                    
                    for row_idx in range(2, ws.max_row + 1):
                        cell_address = ws.cell(row=row_idx, column=excel_col_idx).coordinate
                        if image_loader.image_in(cell_address):
                            # Create safe column name right away
                            safe_col_name = col_name.replace('/', '_').replace('\\', '_').replace(':', '_')
                            image_cells.append((row_idx, excel_col_idx, safe_col_name, cell_address))
                
                # Now extract and save all images
                successful_images = 0
                for row_idx, excel_col_idx, safe_col_name, cell_address in image_cells:
                    try:
                        # Get the image
                        img = image_loader.get(cell_address)
                        
                        # Save path for the image
                        img_path = os.path.join(output_folder, f"{file_name_clean}_Sheet_{sheet_name}_Column_{safe_col_name}_Row_{row_idx}.png")
                        
                        # Save the image directly to the file system
                        with io.BytesIO() as img_buffer:
                            img.save(img_buffer, format="PNG")
                            img_buffer.seek(0)
                            with open(img_path, 'wb') as f:
                                f.write(img_buffer.read())
                        
                        successful_images += 1
                        print(f"✅ Image saved: {img_path}")
                    except Exception as e:
                        print(f"❌ Error saving image at {cell_address} in file '{file_name_clean}': {str(e)}")
                
                print(f"✅ Completed sheet '{sheet_name}': {successful_images}/{len(image_cells)} images saved.")
                successful_sheets += 1
                
            except Exception as e:
                print(f"❌ Error processing sheet '{sheet_name}' in file '{file_name_clean}': {str(e)}")
            
            finally:
                # Always close the workbook after processing each sheet
                if 'wb' in locals() and wb is not None:
                    try:
                        wb.close()
                    except:
                        pass
        
        print(f"✅ Completed processing file: {file_name_clean} ({successful_sheets}/{len(sheet_names)} sheets processed)")
        return True
        
    except Exception as e:
        # Handle any errors in the outer scope
        print(f"❌ Error processing file '{file_path}': {str(e)}")
        return False

def process_excel_folder(folder_path, export_folder): #Process all Excel files in a folder and extract images from them.
    import os
    
    # Create a single "Extract Images" folder within the export directory
    output_folder = os.path.join(export_folder, "Extract Images")
    os.makedirs(output_folder, exist_ok=True)
    
    # Track statistics
    total_files = 0
    successful_files = 0
    failed_files = []
    
    # Get all Excel files in the folder - with full paths
    excel_files = []
    for file in os.listdir(folder_path):
        if file.endswith(('.xlsx', '.xlsm')):
            excel_files.append(os.path.join(folder_path, file))
    
    if not excel_files:
        print("⚠️ No Excel files found in the specified folder.")
        return
    
    total_files = len(excel_files)
    print(f"🔍 Found {total_files} Excel files to process.")
    print(f"🗂️ All images will be saved to: {output_folder}")
    
    # Process each Excel file
    for i, file_path in enumerate(excel_files, 1):
        file_name = os.path.basename(file_path)
        print(f"\n📊 Processing file {i}/{total_files}: {file_name}")
        
        if extract_images_from_excel(file_path, output_folder):
            successful_files += 1
        else:
            failed_files.append(file_name)
    
    # Print summary
    print("\n" + "="*50)
    print("📈 PROCESSING SUMMARY")
    print("="*50)
    print(f"Total files: {total_files}")
    print(f"Successfully processed: {successful_files}")
    print(f"Failed to process: {len(failed_files)}")
    print(f"Images saved to: {output_folder}")
    
    if failed_files:
        print("\nFiles that could not be processed:")
        for file in failed_files:
            print(f"- {file}")
    
    print("\n🎉 All Excel files processing completed!")

# %% [markdown]
# ### 2.2. Run Function

# %%
excel_folder = r"C:\Users\kanzi\Documents\Part Time Job\Data Hasil Survey"  # Path to Excel files
export_folder = r"C:\Users\kanzi\Documents\Part Time Job\Hasil Export"  # Path for export results
        
# Run the function with your paths
process_excel_folder(excel_folder, export_folder)
#extract_images_from_excel(excel_folder, export_folder)
# Out:
# 🔍 Found 29 Excel files to process.
# 🗂️ All images will be saved to: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images
#
# 📊 Processing file 1/29: 01. Cileungsi - Cibeet.xlsx
# c:\Users\kanzi\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
# Processing sheet: RAMBU
# Found 1 'DOKUMENTASI' columns in sheet 'RAMBU'
# ❌ Error saving image at C5 in file '01. Cileungsi - Cibeet': I/O operation on closed file.
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_6.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_7.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_8.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_9.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_10.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_11.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_12.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_13.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_14.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_15.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_16.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_17.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_18.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_19.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_20.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_21.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_22.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_23.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_24.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_25.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_26.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_27.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_28.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_29.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_30.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_31.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_32.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_33.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_34.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_35.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_36.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_37.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_38.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_39.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_40.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_41.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_42.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_43.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_44.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_45.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_46.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_47.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_48.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_49.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_50.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_51.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_52.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_53.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_54.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_55.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_56.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_57.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_58.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_59.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_60.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_61.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_62.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_63.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_64.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_65.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_66.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_67.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_68.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_69.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_70.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_71.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_72.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_73.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_74.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_75.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_76.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_77.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_78.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_79.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_80.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_81.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_82.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_83.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_84.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_85.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_86.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_87.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_88.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_89.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_90.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_91.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_92.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_93.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_94.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_95.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_96.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_97.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_98.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_99.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_100.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_101.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_102.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_103.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_104.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_105.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_106.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_107.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_108.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_109.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_110.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_111.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_112.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_113.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_114.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_115.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_116.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_117.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_118.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_119.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_120.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_121.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_122.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_123.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_124.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_125.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_126.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_127.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_128.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_129.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_130.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_131.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_132.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_133.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_134.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_135.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_136.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_137.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_138.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_139.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_140.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_141.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_142.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_143.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_144.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_145.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_146.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_147.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_148.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_149.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_150.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_151.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_152.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_153.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_154.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_155.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_156.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_157.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_158.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_159.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_160.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_161.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_162.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_163.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_164.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_165.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_166.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_167.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_168.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_169.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_170.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_171.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_172.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_173.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_174.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_175.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_176.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_RAMBU_Column_Dokumentasi_Row_177.png
# ✅ Completed sheet 'RAMBU': 172/173 images saved.
# Processing sheet: PJU
# c:\Users\kanzi\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
# Found 1 'DOKUMENTASI' columns in sheet 'PJU'
# ❌ Error saving image at C5 in file '01. Cileungsi - Cibeet': I/O operation on closed file.
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_6.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_7.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_8.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_9.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_10.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_11.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_12.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_13.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_14.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_15.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_16.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_17.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_18.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_19.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_20.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_21.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_22.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_23.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_24.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_25.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_26.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_27.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_28.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_29.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_30.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_31.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_32.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_33.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_34.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_35.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_36.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_37.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_38.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_39.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_40.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_41.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_42.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_43.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_44.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_45.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_46.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_47.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_48.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_49.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_50.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_51.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_52.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_53.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_54.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_55.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_56.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_57.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_58.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_59.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_60.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_61.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_62.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_63.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_64.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_65.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_66.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_67.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_68.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_69.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_70.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_71.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_72.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_73.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_74.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_75.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_76.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_77.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_78.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_79.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_80.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_81.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_82.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_83.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_84.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_85.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_86.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_87.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_88.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_89.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_90.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_91.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_92.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_93.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_94.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_95.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_96.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_97.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_98.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_99.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_100.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_101.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_102.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_103.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_104.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_105.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_106.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_107.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_108.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_109.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_110.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_111.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_112.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_113.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_114.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_115.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_116.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_117.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_118.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_119.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_120.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_121.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_122.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_123.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_124.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_125.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_126.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_127.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_128.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_129.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_130.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_131.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_132.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_133.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_134.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_135.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_136.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_137.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_138.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_139.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_140.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_141.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_142.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_143.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_144.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_145.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_146.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_147.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_148.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_149.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_150.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_151.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_152.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_153.png
# ✅ Image saved: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\01. Cileungsi - Cibeet_Sheet_PJU_Column_Dokumentasi_Row_154.png
# ...
# ❌ Error saving image at C136 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C137 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C138 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C139 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C140 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C141 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C142 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C143 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C144 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C145 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C146 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C147 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C148 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C149 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C150 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C151 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C152 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C153 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C154 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C155 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C156 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C157 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C158 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C159 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C160 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C161 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C162 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C163 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C164 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C165 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C166 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C167 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C168 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C169 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C170 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C171 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C172 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C173 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C174 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C175 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C176 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C177 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C178 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C179 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C180 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C181 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C182 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C183 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C184 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C185 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C186 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C187 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C188 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C189 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C190 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C191 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C192 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C193 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C194 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C195 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C196 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C197 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C198 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C199 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C200 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C201 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C202 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C203 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C204 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C205 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C206 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C207 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C208 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C209 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C210 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C211 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C212 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C213 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C214 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C215 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C216 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C217 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C218 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C219 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C220 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C221 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C222 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C223 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C224 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C225 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C226 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C227 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C228 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C229 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C230 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C231 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C232 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C233 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C234 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C235 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C236 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C237 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C238 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C239 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ❌ Error saving image at C240 in file '02. CILEUNGSI - CIBINONG (CITEUREUP)': I/O operation on closed file.
# ✅ Completed sheet 'PAGAR PENGAMAN': 0/236 images saved.
# Processing sheet: MARKA
# c:\Users\kanzi\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 5
#       2 export_folder = r"C:\Users\kanzi\Documents\Part Time Job\Hasil Export"  # Path for export results
#       4 # Run the function with your paths
# ----> 5 process_excel_folder(excel_folder, export_folder)
#       6 #extract_images_from_excel(excel_folder, export_folder)
#
# Cell In[4], line 214, in process_excel_folder(folder_path, export_folder)
#     211 file_name = os.path.basename(file_path)
#     212 print(f"\n📊 Processing file {i}/{total_files}: {file_name}")
# --> 214 if extract_images_from_excel(file_path, output_folder):
#     215     successful_files += 1
#     216 else:
#
# Cell In[4], line 55, in extract_images_from_excel(file_path, output_folder)
#      52 print(f"Processing sheet: {sheet_name}")
#      54 # Open a fresh workbook instance for each sheet
# ---> 55 wb = load_workbook(file_path, data_only=True)
#      56 ws = wb[sheet_name]
#      58 # Create a fresh image loader for this sheet
#
# File c:\Users\kanzi\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\reader\excel.py:348, in load_workbook(filename, read_only, keep_vba, data_only, keep_links, rich_text)
#     318 """Open the given filename and return the workbook
#     319
#     320 :param filename: the path to open or a file-like object
#    (...)
#     344
#     345 """
#     346 reader = ExcelReader(filename, read_only, keep_vba,
#     347                      data_only, keep_links, rich_text)
# --> 348 reader.read()
#     349 return reader.wb
#
# File c:\Users\kanzi\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\reader\excel.py:303, in ExcelReader.read(self)
#     301 apply_stylesheet(self.archive, self.wb)
#     302 action = "read worksheets"
# --> 303 self.read_worksheets()
#     304 action = "assign names"
#     305 self.parser.assign_names()
#
# File c:\Users\kanzi\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\reader\excel.py:237, in ExcelReader.read_worksheets(self)
#     235     ws._rels = rels
#     236     ws_parser = WorksheetReader(ws, fh, self.shared_strings, self.data_only, self.rich_text)
# --> 237     ws_parser.bind_all()
#     238     fh.close()
#     240 # assign any comments to cells
#
# File c:\Users\kanzi\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\worksheet\_reader.py:465, in WorksheetReader.bind_all(self)
#     464 def bind_all(self):
# --> 465     self.bind_cells()
#     466     self.bind_merged_cells()
#     467     self.bind_hyperlinks()
#
# File c:\Users\kanzi\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\worksheet\_reader.py:368, in WorksheetReader.bind_cells(self)
#     367 def bind_cells(self):
# --> 368     for idx, row in self.parser.parse():
#     369         for cell in row:
#     370             style = self.ws.parent._cell_styles[cell['style_id']]
#
# File c:\Users\kanzi\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\worksheet\_reader.py:156, in WorkSheetParser.parse(self)
#     137 properties = {
#     138     PRINT_TAG: ('print_options', PrintOptions),
#     139     MARGINS_TAG: ('page_margins', PageMargins),
#    (...)
#     151
#     152 }
#     154 it = iterparse(self.source) # add a finaliser to close the source when this becomes possible
# --> 156 for _, element in it:
#     157     tag_name = element.tag
#     158     if tag_name in dispatcher:
#
# File c:\Users\kanzi\AppData\Local\Programs\Python\Python312\Lib\xml\etree\ElementTree.py:1236, in iterparse.<locals>.iterator(source)
#    1234 yield from pullparser.read_events()
#    1235 # load event buffer
# -> 1236 data = source.read(16 * 1024)
#    1237 if not data:
#    1238     break
#
# File c:\Users\kanzi\AppData\Local\Programs\Python\Python312\Lib\zipfile\__init__.py:978, in ZipExtFile.read(self, n)
#     976 self._offset = 0
#     977 while n > 0 and not self._eof:
# --> 978     data = self._read1(n)
#     979     if n < len(data):
#     980         self._readbuffer = data
#
# File c:\Users\kanzi\AppData\Local\Programs\Python\Python312\Lib\zipfile\__init__.py:1054, in ZipExtFile._read1(self, n)
#    1052 elif self._compress_type == ZIP_DEFLATED:
#    1053     n = max(n, self.MIN_READ_SIZE)
# -> 1054     data = self._decompressor.decompress(data, n)
#    1055     self._eof = (self._decompressor.eof or
#    1056                  self._compress_left <= 0 and
#    1057                  not self._decompressor.unconsumed_tail)
#    1058     if self._eof:
#
# KeyboardInterrupt:
