# %% [markdown]
# # Application to Extract Image from Excel

# %% [markdown]
# ## 1. Import Library

# %%
import os
import pandas as pd
from openpyxl_image_loader import SheetImageLoader
from openpyxl import load_workbook
from openpyxl.drawing.image import Image
from PIL import Image
import io
import re
import gc
from concurrent.futures import ThreadPoolExecutor
import time
from io import BytesIO
from openpyxl.utils import column_index_from_string, get_column_letter
from lxml import etree
import zipfile
import shutil
import xml.etree.ElementTree as ET
from PIL import Image as PILImage
from collections import defaultdict

# %% [markdown]
# ## 2. Application to Extract Images from Excel

# %% [markdown]
# ### 2.1. Function Codes

# %%
def extract_images_from_excel(file_path, output_folder):
    """Extract images from columns containing specific keywords in all sheets and save them."""
    import re
    import os
    import io
    import pandas as pd
    from openpyxl import load_workbook
    from openpyxl_image_loader import SheetImageLoader
    from openpyxl.utils import get_column_letter, column_index_from_string
    
    # Keywords to look for in column names
    KEYWORDS = ["DOKUMENTASI", "RAMBU", "RPPJ"]
    
    # Create subdirectories for each category
    dokumentasi_folder = os.path.join(output_folder, "Dokumentasi")
    rambu_folder = os.path.join(output_folder, "Rambu")
    rppj_folder = os.path.join(output_folder, "RPPJ")
    
    for folder in [dokumentasi_folder, rambu_folder, rppj_folder]:
        os.makedirs(folder, exist_ok=True)
    
    try:
        # Extract filename from path
        file_name_clean = re.search(r'([^\\]+)\.xlsx$', file_path)
        if file_name_clean:
            file_name_clean = file_name_clean.group(1)
        else:
            file_name_clean = os.path.basename(file_path).replace('.xlsx', '')
        
        # Process each sheet independently to prevent file handle issues
        wb = load_workbook(file_path, data_only=True)
        sheet_names = wb.sheetnames.copy()  # Make a copy of sheet names before closing
        wb.close()  # Close immediately to avoid keeping file handles open
        
        successful_sheets = 0
        total_images_saved = 0
        
        # Process sheets in the order they appear in the workbook
        for sheet_idx, sheet_name in enumerate(sheet_names, 1):
            try:
                print(f"Processing sheet {sheet_idx}/{len(sheet_names)}: {sheet_name}")
                
                # Create a safe sheet name for filenames
                safe_sheet_name = re.sub(r'[\\/*?:"<>|]', "_", sheet_name)
                
                # Open a fresh workbook instance for each sheet
                wb = load_workbook(file_path, data_only=True)
                ws = wb[sheet_name]
                
                # Create a fresh image loader for this sheet
                image_loader = SheetImageLoader(ws)
                
                # Step 1: Extract merged column headers from rows 1-5
                # This creates a mapping from column index to full column name
                column_names = {}
                
                # Get values for rows 1-5 for each column
                for col in range(1, ws.max_column + 1):
                    col_letter = get_column_letter(col)
                    header_values = []
                    
                    for row in range(1, 6):  # Rows 1-5
                        cell_value = ws[f"{col_letter}{row}"].value
                        if cell_value:
                            header_values.append(str(cell_value).strip())
                    
                    # Combine the header parts into one name
                    if header_values:
                        column_names[col] = " ".join(header_values)
                    else:
                        column_names[col] = f"Column_{col_letter}"
                
                # Step 2: Find columns containing our keywords
                dokumentasi_columns = {}
                rambu_columns = {}
                rppj_columns = {}
                nama_rambu_column = None
                jenis_tiang_column = None
                
                # First, find all our target columns
                for col, name in column_names.items():
                    if "DOKUMENTASI" in name.upper():
                        dokumentasi_columns[col] = name
                    elif "RAMBU" in name.upper() and "NAMA RAMBU" not in name.upper():
                        rambu_columns[col] = name
                    elif "RPPJ" in name.upper():
                        rppj_columns[col] = name
                    
                    # Find the specific column for "Nama Rambu"
                    if "NAMA RAMBU" in name.upper():
                        nama_rambu_column = col
                        print(f"Found 'Nama Rambu' column: {name} (Column {get_column_letter(col)})")
                    
                    # Find the specific column for "Jenis Tiang"
                    elif "JENIS TIANG" in name.upper():
                        jenis_tiang_column = col
                        print(f"Found 'Jenis Tiang' column: {name} (Column {get_column_letter(col)})")
                
                # Track images processed for each category
                images_by_category = {
                    "dokumentasi": 0,
                    "rambu": 0,
                    "rppj": 0
                }
                
                # Process each category separately
                
                # 1. Process DOKUMENTASI columns
                if dokumentasi_columns:
                    processed = process_image_columns(
                        ws, image_loader, dokumentasi_columns, dokumentasi_folder, 
                        file_name_clean, safe_sheet_name, "dokumentasi", None, None
                    )
                    images_by_category["dokumentasi"] += processed
                
                # 2. Process RAMBU columns (custom naming based on "Nama Rambu" column)
                if rambu_columns:
                    if nama_rambu_column is None:
                        print("⚠️ Warning: 'Nama Rambu' column not found. Using default naming for Rambu images.")
                    
                    processed = process_image_columns(
                        ws, image_loader, rambu_columns, rambu_folder, 
                        file_name_clean, safe_sheet_name, "rambu", nama_rambu_column, None
                    )
                    images_by_category["rambu"] += processed
                
                # 3. Process RPPJ columns (custom naming based on "Jenis Tiang" column)
                if rppj_columns:
                    if jenis_tiang_column is None:
                        print("⚠️ Warning: 'Jenis Tiang' column not found. Using default naming for RPPJ images.")
                    
                    processed = process_image_columns(
                        ws, image_loader, rppj_columns, rppj_folder, 
                        file_name_clean, safe_sheet_name, "rppj", None, jenis_tiang_column
                    )
                    images_by_category["rppj"] += processed
                
                total_images_saved += sum(images_by_category.values())
                
                print(f"✅ Completed sheet '{sheet_name}':")
                print(f"  - Dokumentasi: {images_by_category['dokumentasi']} images")
                print(f"  - Rambu: {images_by_category['rambu']} images")
                print(f"  - RPPJ: {images_by_category['rppj']} images")
                
                if sum(images_by_category.values()) > 0:
                    successful_sheets += 1
                
            except Exception as e:
                print(f"❌ Error processing sheet '{sheet_name}' in file '{file_name_clean}': {str(e)}")
            
            finally:
                # Always close the workbook after processing each sheet
                if 'wb' in locals() and wb is not None:
                    try:
                        wb.close()
                    except:
                        pass
        
        print(f"✅ Completed processing file: {file_name_clean}")
        print(f"  - {successful_sheets}/{len(sheet_names)} sheets processed")
        print(f"  - {total_images_saved} total images extracted")
        return True
        
    except Exception as e:
        # Handle any errors in the outer scope
        print(f"❌ Error processing file '{file_path}': {str(e)}")
        return False


def process_image_columns(ws, image_loader, target_columns, output_folder, file_name_clean, 
                          safe_sheet_name, category, nama_rambu_column, jenis_tiang_column):
    """Process images in specified columns with custom naming logic."""
    import re
    import os
    import io
    from openpyxl.utils import get_column_letter
    
    # Track existing image names (to avoid duplicates for Rambu)
    existing_images = {}
    
    # Find image cells in target columns
    image_cells = {}
    for col in target_columns:
        col_letter = get_column_letter(col)
        column_name = target_columns[col]
        
        # Make column name safe for filename
        safe_column_name = re.sub(r'[\\/*?:"<>|]', "_", column_name)
        
        # Scan rows starting from row 6
        for row in range(6, ws.max_row + 1):
            cell_address = f"{col_letter}{row}"
            if image_loader.image_in(cell_address):
                image_cells[(row, col)] = {
                    'cell_address': cell_address,
                    'column_name': safe_column_name,
                    'column_letter': col_letter,
                    'row_number': row
                }
    
    if not image_cells:
        print(f"⚠️ No images found in {category.upper()} columns, skipping...")
        return 0
    
    print(f"Found {len(image_cells)} images in {category.upper()} columns")
    
    # Process images in column-first, row-second order
    successful_images = 0
    image_cells_by_column = {}
    
    # Group by column
    for (row, col), cell_info in image_cells.items():
        if col not in image_cells_by_column:
            image_cells_by_column[col] = []
        image_cells_by_column[col].append((row, cell_info))
    
    # Process each column
    for col in sorted(image_cells_by_column.keys()):
        column_letter = get_column_letter(col)
        column_name = target_columns[col]
        safe_column_name = re.sub(r'[\\/*?:"<>|]', "_", column_name)
        
        print(f"Processing {len(image_cells_by_column[col])} images in column '{column_name}'")
        
        # Process rows in order
        for row, cell_info in sorted(image_cells_by_column[col], key=lambda x: x[0]):
            cell_address = cell_info['cell_address']
            try:
                # Get the image
                img = image_loader.get(cell_address)
                
                # Generate filename based on category
                if category == "rambu" and nama_rambu_column is not None:
                    # For RAMBU: Use "Nama Rambu" column value as filename
                    nama_rambu_value = ws[f"{get_column_letter(nama_rambu_column)}{row}"].value
                    
                    if nama_rambu_value and str(nama_rambu_value).strip():
                        # Use the actual value from "Nama Rambu" column
                        safe_nama_rambu = re.sub(r'[\\/*?:"<>|]', "_", str(nama_rambu_value).strip())
                        img_filename = f"{safe_nama_rambu}.png"
                        
                        # Check if this name already exists (to avoid duplicates)
                        if img_filename in existing_images:
                            print(f"  ⚠️ Duplicate 'Nama Rambu' found: {safe_nama_rambu} - Replacing existing image")
                        
                        existing_images[img_filename] = True
                    else:
                        # Fallback to default naming if no nama_rambu value
                        print(f"  ⚠️ No 'Nama Rambu' value found for row {row}, using default naming")
                        row_identifier = f"Row{row}"
                        safe_row_identifier = re.sub(r'[\\/*?:"<>|]', "_", row_identifier)
                        img_filename = f"{file_name_clean}_Sheet_{safe_sheet_name}_Column_{safe_column_name}_{safe_row_identifier}.png"
                
                elif category == "rppj" and jenis_tiang_column is not None:
                    # For RPPJ: Use "Jenis Tiang" column value in filename
                    jenis_tiang_value = ws[f"{get_column_letter(jenis_tiang_column)}{row}"].value
                    safe_jenis_tiang = "Unknown"
                    if jenis_tiang_value and str(jenis_tiang_value).strip():
                        safe_jenis_tiang = re.sub(r'[\\/*?:"<>|]', "_", str(jenis_tiang_value).strip())
                    
                    # Get row identifier - ALWAYS use just the row number without column A value
                    row_identifier = f"Row{row}"
                    
                    safe_row_identifier = re.sub(r'[\\/*?:"<>|]', "_", row_identifier)
                    img_filename = f"{file_name_clean}_Sheet_{safe_sheet_name}_Column_{safe_jenis_tiang}_{safe_row_identifier}.png"
                
                else:
                    # Default naming for DOKUMENTASI (and fallback for others)
                    # ALWAYS use just the row number without column A value
                    row_identifier = f"Row{row}"
                    
                    safe_row_identifier = re.sub(r'[\\/*?:"<>|]', "_", row_identifier)
                    img_filename = f"{file_name_clean}_Sheet_{safe_sheet_name}_Column_{safe_column_name}_{safe_row_identifier}.png"
                
                # Save the image
                img_path = os.path.join(output_folder, img_filename)
                with io.BytesIO() as img_buffer:
                    img.save(img_buffer, format="PNG")
                    img_buffer.seek(0)
                    with open(img_path, 'wb') as f:
                        f.write(img_buffer.read())
                
                successful_images += 1
                print(f"  ✅ Saved: {img_filename}")
            except Exception as e:
                print(f"  ❌ Error saving image at {cell_address}: {str(e)}")
    
    return successful_images


def process_excel_folder(folder_path, export_folder):
    """Process all Excel files in a folder and extract images from them."""
    import os
    
    # Create "Extract Images" folder within the export directory
    output_folder = os.path.join(export_folder, "Extract Images")
    os.makedirs(output_folder, exist_ok=True)
    
    # Track statistics
    total_files = 0
    successful_files = 0
    failed_files = []
    
    # Get all Excel files in the folder - with full paths
    excel_files = []
    for file in os.listdir(folder_path):
        if file.endswith(('.xlsx', '.xlsm')):
            excel_files.append(os.path.join(folder_path, file))
    
    if not excel_files:
        print("⚠️ No Excel files found in the specified folder.")
        return
    
    total_files = len(excel_files)
    print(f"🔍 Found {total_files} Excel files to process.")
    print(f"🗂️ All images will be saved to: {output_folder}")
    print(f"   - Dokumentasi images: {os.path.join(output_folder, 'Dokumentasi')}")
    print(f"   - Rambu images: {os.path.join(output_folder, 'Rambu')}")
    print(f"   - RPPJ images: {os.path.join(output_folder, 'RPPJ')}")
    
    # Process each Excel file
    for i, file_path in enumerate(excel_files, 1):
        file_name = os.path.basename(file_path)
        print(f"\n📊 Processing file {i}/{total_files}: {file_name}")
        
        if extract_images_from_excel(file_path, output_folder):
            successful_files += 1
        else:
            failed_files.append(file_name)
    
    # Print summary
    print("\n" + "="*50)
    print("📈 PROCESSING SUMMARY")
    print("="*50)
    print(f"Total files: {total_files}")
    print(f"Successfully processed: {successful_files}")
    print(f"Failed to process: {len(failed_files)}")
    print(f"Images saved to: {output_folder}")
    
    if failed_files:
        print("\nFiles that could not be processed:")
        for file in failed_files:
            print(f"- {file}")
    
    print("\n🎉 All Excel files processing completed!")

# %% [markdown]
# ### 2.2. Run Function

# %%
excel_folder = r"C:\Users\kanzi\Documents\Part Time Job\Data Hasil Survey"  # Path to Excel files
export_folder = r"C:\Users\kanzi\Documents\Part Time Job\Hasil Export"  # Path for export results
        
# Run the function with your paths
process_excel_folder(excel_folder, export_folder)
#extract_images_from_excel(excel_folder, export_folder)
# Out:
# 🔍 Found 1 Excel files to process.
# 🗂️ All images will be saved to: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images
#    - Dokumentasi images: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\Dokumentasi
#    - Rambu images: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\Rambu
#    - RPPJ images: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images\RPPJ
#
# 📊 Processing file 1/1: 02. CILEUNGSI - CIBINONG (CITEUREUP).xlsx
# Processing sheet 1/13: RAMBU
# Found 'Nama Rambu' column: NAMA RAMBU (Column F)
# Found 469 images in DOKUMENTASI columns
# Processing 469 images in column 'DOKUMENTASI'
#   ❌ Error saving image at C6: I/O operation on closed file.
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_RAMBU_Column_DOKUMENTASI_Row7.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_RAMBU_Column_DOKUMENTASI_Row8.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_RAMBU_Column_DOKUMENTASI_Row9.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_RAMBU_Column_DOKUMENTASI_Row10.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_RAMBU_Column_DOKUMENTASI_Row11.png
#   ❌ Error saving image at C12: I/O operation on closed file.
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_RAMBU_Column_DOKUMENTASI_Row13.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_RAMBU_Column_DOKUMENTASI_Row14.png
#   ❌ Error saving image at C15: I/O operation on closed file.
#   ❌ Error saving image at C16: I/O operation on closed file.
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_RAMBU_Column_DOKUMENTASI_Row17.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_RAMBU_Column_DOKUMENTASI_Row18.png
#   ❌ Error saving image at C19: I/O operation on closed file.
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_RAMBU_Column_DOKUMENTASI_Row20.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_RAMBU_Column_DOKUMENTASI_Row21.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_RAMBU_Column_DOKUMENTASI_Row22.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_RAMBU_Column_DOKUMENTASI_Row23.png
#   ❌ Error saving image at C24: I/O operation on closed file.
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_RAMBU_Column_DOKUMENTASI_Row25.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_RAMBU_Column_DOKUMENTASI_Row26.png
#   ❌ Error saving image at C27: I/O operation on closed file.
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_RAMBU_Column_DOKUMENTASI_Row28.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_RAMBU_Column_DOKUMENTASI_Row29.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_RAMBU_Column_DOKUMENTASI_Row30.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_RAMBU_Column_DOKUMENTASI_Row31.png
#   ❌ Error saving image at C32: I/O operation on closed file.
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_RAMBU_Column_DOKUMENTASI_Row33.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_RAMBU_Column_DOKUMENTASI_Row34.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_RAMBU_Column_DOKUMENTASI_Row35.png
#   ❌ Error saving image at C36: I/O operation on closed file.
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_RAMBU_Column_DOKUMENTASI_Row37.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_RAMBU_Column_DOKUMENTASI_Row38.png
#   ❌ Error saving image at C39: I/O operation on closed file.
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_RAMBU_Column_DOKUMENTASI_Row40.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_RAMBU_Column_DOKUMENTASI_Row41.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_RAMBU_Column_DOKUMENTASI_Row42.png
#   ❌ Error saving image at C43: I/O operation on closed file.
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_RAMBU_Column_DOKUMENTASI_Row44.png
#   ❌ Error saving image at C45: I/O operation on closed file.
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_RAMBU_Column_DOKUMENTASI_Row46.png
#   ❌ Error saving image at C47: I/O operation on closed file.
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_RAMBU_Column_DOKUMENTASI_Row48.png
#   ❌ Error saving image at C49: I/O operation on closed file.
#   ❌ Error saving image at C50: I/O operation on closed file.
#   ❌ Error saving image at C51: I/O operation on closed file.
#   ❌ Error saving image at C52: I/O operation on closed file.
#   ❌ Error saving image at C53: I/O operation on closed file.
#   ❌ Error saving image at C54: I/O operation on closed file.
#   ❌ Error saving image at C55: I/O operation on closed file.
#   ❌ Error saving image at C56: I/O operation on closed file.
#   ❌ Error saving image at C57: I/O operation on closed file.
#   ❌ Error saving image at C58: I/O operation on closed file.
#   ❌ Error saving image at C59: I/O operation on closed file.
#   ❌ Error saving image at C60: I/O operation on closed file.
#   ❌ Error saving image at C61: I/O operation on closed file.
#   ❌ Error saving image at C62: I/O operation on closed file.
#   ❌ Error saving image at C63: I/O operation on closed file.
#   ❌ Error saving image at C64: I/O operation on closed file.
#   ❌ Error saving image at C65: I/O operation on closed file.
#   ❌ Error saving image at C66: I/O operation on closed file.
#   ❌ Error saving image at C67: I/O operation on closed file.
#   ❌ Error saving image at C68: I/O operation on closed file.
#   ❌ Error saving image at C69: I/O operation on closed file.
#   ❌ Error saving image at C70: I/O operation on closed file.
#   ❌ Error saving image at C71: I/O operation on closed file.
#   ❌ Error saving image at C72: I/O operation on closed file.
#   ❌ Error saving image at C73: I/O operation on closed file.
#   ❌ Error saving image at C74: I/O operation on closed file.
#   ❌ Error saving image at C75: I/O operation on closed file.
#   ❌ Error saving image at C76: I/O operation on closed file.
#   ❌ Error saving image at C77: I/O operation on closed file.
#   ❌ Error saving image at C78: I/O operation on closed file.
#   ❌ Error saving image at C79: I/O operation on closed file.
#   ❌ Error saving image at C80: I/O operation on closed file.
#   ❌ Error saving image at C81: I/O operation on closed file.
#   ❌ Error saving image at C82: I/O operation on closed file.
#   ❌ Error saving image at C83: I/O operation on closed file.
#   ❌ Error saving image at C84: I/O operation on closed file.
#   ❌ Error saving image at C85: I/O operation on closed file.
#   ❌ Error saving image at C86: I/O operation on closed file.
#   ❌ Error saving image at C87: I/O operation on closed file.
#   ❌ Error saving image at C88: I/O operation on closed file.
#   ❌ Error saving image at C89: I/O operation on closed file.
#   ❌ Error saving image at C90: I/O operation on closed file.
#   ❌ Error saving image at C91: I/O operation on closed file.
#   ❌ Error saving image at C92: I/O operation on closed file.
#   ❌ Error saving image at C93: I/O operation on closed file.
#   ❌ Error saving image at C94: I/O operation on closed file.
#   ❌ Error saving image at C95: I/O operation on closed file.
#   ❌ Error saving image at C96: I/O operation on closed file.
#   ❌ Error saving image at C97: I/O operation on closed file.
#   ❌ Error saving image at C98: I/O operation on closed file.
#   ❌ Error saving image at C99: I/O operation on closed file.
#   ❌ Error saving image at C100: I/O operation on closed file.
#   ❌ Error saving image at C101: I/O operation on closed file.
#   ❌ Error saving image at C102: I/O operation on closed file.
#   ❌ Error saving image at C103: I/O operation on closed file.
#   ❌ Error saving image at C104: I/O operation on closed file.
#   ❌ Error saving image at C105: I/O operation on closed file.
#   ❌ Error saving image at C106: I/O operation on closed file.
#   ❌ Error saving image at C107: I/O operation on closed file.
#   ❌ Error saving image at C108: I/O operation on closed file.
#   ❌ Error saving image at C109: I/O operation on closed file.
#   ❌ Error saving image at C110: I/O operation on closed file.
#   ❌ Error saving image at C111: I/O operation on closed file.
#   ❌ Error saving image at C112: I/O operation on closed file.
#   ❌ Error saving image at C113: I/O operation on closed file.
#   ❌ Error saving image at C114: I/O operation on closed file.
#   ❌ Error saving image at C115: I/O operation on closed file.
#   ❌ Error saving image at C116: I/O operation on closed file.
#   ❌ Error saving image at C117: I/O operation on closed file.
#   ❌ Error saving image at C118: I/O operation on closed file.
#   ❌ Error saving image at C119: I/O operation on closed file.
#   ❌ Error saving image at C120: I/O operation on closed file.
#   ❌ Error saving image at C121: I/O operation on closed file.
#   ❌ Error saving image at C122: I/O operation on closed file.
#   ❌ Error saving image at C123: I/O operation on closed file.
#   ❌ Error saving image at C124: I/O operation on closed file.
#   ❌ Error saving image at C125: I/O operation on closed file.
#   ❌ Error saving image at C126: I/O operation on closed file.
#   ❌ Error saving image at C127: I/O operation on closed file.
#   ❌ Error saving image at C128: I/O operation on closed file.
#   ❌ Error saving image at C129: I/O operation on closed file.
#   ❌ Error saving image at C130: I/O operation on closed file.
#   ❌ Error saving image at C131: I/O operation on closed file.
#   ❌ Error saving image at C132: I/O operation on closed file.
#   ❌ Error saving image at C133: I/O operation on closed file.
#   ❌ Error saving image at C134: I/O operation on closed file.
#   ❌ Error saving image at C135: I/O operation on closed file.
#   ❌ Error saving image at C136: I/O operation on closed file.
#   ❌ Error saving image at C137: I/O operation on closed file.
#   ❌ Error saving image at C138: I/O operation on closed file.
#   ❌ Error saving image at C139: I/O operation on closed file.
#   ❌ Error saving image at C140: I/O operation on closed file.
#   ❌ Error saving image at C141: I/O operation on closed file.
#   ❌ Error saving image at C142: I/O operation on closed file.
#   ❌ Error saving image at C143: I/O operation on closed file.
#   ❌ Error saving image at C144: I/O operation on closed file.
#   ❌ Error saving image at C145: I/O operation on closed file.
#   ❌ Error saving image at C146: I/O operation on closed file.
#   ❌ Error saving image at C147: I/O operation on closed file.
#   ❌ Error saving image at C148: I/O operation on closed file.
#   ❌ Error saving image at C149: I/O operation on closed file.
#   ❌ Error saving image at C150: I/O operation on closed file.
#   ❌ Error saving image at C151: I/O operation on closed file.
#   ❌ Error saving image at C152: I/O operation on closed file.
#   ❌ Error saving image at C153: I/O operation on closed file.
#   ❌ Error saving image at C154: I/O operation on closed file.
#   ❌ Error saving image at C155: I/O operation on closed file.
#   ❌ Error saving image at C156: I/O operation on closed file.
#   ❌ Error saving image at C157: I/O operation on closed file.
#   ❌ Error saving image at C158: I/O operation on closed file.
#   ❌ Error saving image at C159: I/O operation on closed file.
#   ❌ Error saving image at C160: I/O operation on closed file.
#   ❌ Error saving image at C161: I/O operation on closed file.
#   ❌ Error saving image at C162: I/O operation on closed file.
#   ❌ Error saving image at C163: I/O operation on closed file.
#   ❌ Error saving image at C164: I/O operation on closed file.
#   ❌ Error saving image at C165: I/O operation on closed file.
#   ❌ Error saving image at C166: I/O operation on closed file.
#   ❌ Error saving image at C167: I/O operation on closed file.
#   ❌ Error saving image at C168: I/O operation on closed file.
#   ❌ Error saving image at C169: I/O operation on closed file.
#   ❌ Error saving image at C170: I/O operation on closed file.
#   ❌ Error saving image at C171: I/O operation on closed file.
#   ❌ Error saving image at C172: I/O operation on closed file.
#   ❌ Error saving image at C173: I/O operation on closed file.
#   ❌ Error saving image at C174: I/O operation on closed file.
#   ❌ Error saving image at C175: I/O operation on closed file.
#   ❌ Error saving image at C176: I/O operation on closed file.
#   ❌ Error saving image at C177: I/O operation on closed file.
#   ❌ Error saving image at C178: I/O operation on closed file.
#   ❌ Error saving image at C179: I/O operation on closed file.
#   ❌ Error saving image at C180: I/O operation on closed file.
#   ❌ Error saving image at C181: I/O operation on closed file.
#   ❌ Error saving image at C182: I/O operation on closed file.
#   ❌ Error saving image at C183: I/O operation on closed file.
#   ❌ Error saving image at C184: I/O operation on closed file.
#   ❌ Error saving image at C185: I/O operation on closed file.
#   ❌ Error saving image at C186: I/O operation on closed file.
#   ❌ Error saving image at C187: I/O operation on closed file.
#   ❌ Error saving image at C188: I/O operation on closed file.
#   ❌ Error saving image at C189: I/O operation on closed file.
#   ❌ Error saving image at C190: I/O operation on closed file.
#   ❌ Error saving image at C191: I/O operation on closed file.
#   ❌ Error saving image at C192: I/O operation on closed file.
#   ❌ Error saving image at C193: I/O operation on closed file.
#   ❌ Error saving image at C194: I/O operation on closed file.
#   ❌ Error saving image at C195: I/O operation on closed file.
#   ❌ Error saving image at C196: I/O operation on closed file.
#   ❌ Error saving image at C197: I/O operation on closed file.
#   ❌ Error saving image at C198: I/O operation on closed file.
#   ❌ Error saving image at C199: I/O operation on closed file.
#   ❌ Error saving image at C200: I/O operation on closed file.
#   ❌ Error saving image at C201: I/O operation on closed file.
#   ❌ Error saving image at C202: I/O operation on closed file.
#   ❌ Error saving image at C203: I/O operation on closed file.
#   ❌ Error saving image at C204: I/O operation on closed file.
#   ❌ Error saving image at C205: I/O operation on closed file.
#   ❌ Error saving image at C206: I/O operation on closed file.
#   ❌ Error saving image at C207: I/O operation on closed file.
#   ❌ Error saving image at C208: I/O operation on closed file.
#   ❌ Error saving image at C209: I/O operation on closed file.
#   ❌ Error saving image at C210: I/O operation on closed file.
#   ❌ Error saving image at C211: I/O operation on closed file.
#   ❌ Error saving image at C212: I/O operation on closed file.
#   ❌ Error saving image at C213: I/O operation on closed file.
#   ❌ Error saving image at C214: I/O operation on closed file.
#   ❌ Error saving image at C215: I/O operation on closed file.
#   ❌ Error saving image at C216: I/O operation on closed file.
#   ❌ Error saving image at C217: I/O operation on closed file.
#   ❌ Error saving image at C218: I/O operation on closed file.
#   ❌ Error saving image at C219: I/O operation on closed file.
#   ❌ Error saving image at C220: I/O operation on closed file.
#   ❌ Error saving image at C221: I/O operation on closed file.
#   ❌ Error saving image at C222: I/O operation on closed file.
#   ❌ Error saving image at C223: I/O operation on closed file.
#   ❌ Error saving image at C224: I/O operation on closed file.
#   ❌ Error saving image at C225: I/O operation on closed file.
#   ❌ Error saving image at C226: I/O operation on closed file.
#   ❌ Error saving image at C227: I/O operation on closed file.
#   ❌ Error saving image at C228: I/O operation on closed file.
#   ❌ Error saving image at C229: I/O operation on closed file.
#   ❌ Error saving image at C230: I/O operation on closed file.
#   ❌ Error saving image at C231: I/O operation on closed file.
#   ❌ Error saving image at C232: I/O operation on closed file.
#   ❌ Error saving image at C233: I/O operation on closed file.
#   ❌ Error saving image at C234: I/O operation on closed file.
#   ❌ Error saving image at C235: I/O operation on closed file.
#   ❌ Error saving image at C236: I/O operation on closed file.
#   ❌ Error saving image at C237: I/O operation on closed file.
#   ❌ Error saving image at C238: I/O operation on closed file.
#   ❌ Error saving image at C239: I/O operation on closed file.
#   ❌ Error saving image at C240: I/O operation on closed file.
#   ❌ Error saving image at C241: I/O operation on closed file.
#   ❌ Error saving image at C242: I/O operation on closed file.
#   ❌ Error saving image at C243: I/O operation on closed file.
#   ❌ Error saving image at C244: I/O operation on closed file.
#   ❌ Error saving image at C245: I/O operation on closed file.
#   ❌ Error saving image at C246: I/O operation on closed file.
#   ❌ Error saving image at C247: I/O operation on closed file.
#   ❌ Error saving image at C248: I/O operation on closed file.
#   ❌ Error saving image at C249: I/O operation on closed file.
#   ❌ Error saving image at C250: I/O operation on closed file.
#   ❌ Error saving image at C251: I/O operation on closed file.
#   ❌ Error saving image at C252: I/O operation on closed file.
#   ❌ Error saving image at C253: I/O operation on closed file.
#   ❌ Error saving image at C254: I/O operation on closed file.
#   ❌ Error saving image at C255: I/O operation on closed file.
#   ❌ Error saving image at C256: I/O operation on closed file.
#   ❌ Error saving image at C257: I/O operation on closed file.
#   ❌ Error saving image at C258: I/O operation on closed file.
#   ❌ Error saving image at C259: I/O operation on closed file.
#   ❌ Error saving image at C260: I/O operation on closed file.
#   ❌ Error saving image at C261: I/O operation on closed file.
#   ❌ Error saving image at C262: I/O operation on closed file.
#   ❌ Error saving image at C263: I/O operation on closed file.
#   ❌ Error saving image at C264: I/O operation on closed file.
#   ❌ Error saving image at C265: I/O operation on closed file.
#   ❌ Error saving image at C266: I/O operation on closed file.
#   ❌ Error saving image at C267: I/O operation on closed file.
#   ❌ Error saving image at C268: I/O operation on closed file.
#   ❌ Error saving image at C269: I/O operation on closed file.
#   ❌ Error saving image at C270: I/O operation on closed file.
#   ❌ Error saving image at C271: I/O operation on closed file.
#   ❌ Error saving image at C272: I/O operation on closed file.
#   ❌ Error saving image at C273: I/O operation on closed file.
#   ❌ Error saving image at C274: I/O operation on closed file.
#   ❌ Error saving image at C275: I/O operation on closed file.
#   ❌ Error saving image at C276: I/O operation on closed file.
#   ❌ Error saving image at C277: I/O operation on closed file.
#   ❌ Error saving image at C278: I/O operation on closed file.
#   ❌ Error saving image at C279: I/O operation on closed file.
#   ❌ Error saving image at C280: I/O operation on closed file.
#   ❌ Error saving image at C281: I/O operation on closed file.
#   ❌ Error saving image at C282: I/O operation on closed file.
#   ❌ Error saving image at C283: I/O operation on closed file.
#   ❌ Error saving image at C284: I/O operation on closed file.
#   ❌ Error saving image at C285: I/O operation on closed file.
#   ❌ Error saving image at C286: I/O operation on closed file.
#   ❌ Error saving image at C287: I/O operation on closed file.
#   ❌ Error saving image at C288: I/O operation on closed file.
#   ❌ Error saving image at C289: I/O operation on closed file.
#   ❌ Error saving image at C290: I/O operation on closed file.
#   ❌ Error saving image at C291: I/O operation on closed file.
#   ❌ Error saving image at C292: I/O operation on closed file.
#   ❌ Error saving image at C293: I/O operation on closed file.
#   ❌ Error saving image at C294: I/O operation on closed file.
#   ❌ Error saving image at C295: I/O operation on closed file.
#   ❌ Error saving image at C296: I/O operation on closed file.
#   ❌ Error saving image at C297: I/O operation on closed file.
#   ❌ Error saving image at C298: I/O operation on closed file.
#   ❌ Error saving image at C299: I/O operation on closed file.
#   ❌ Error saving image at C300: I/O operation on closed file.
#   ❌ Error saving image at C301: I/O operation on closed file.
#   ❌ Error saving image at C302: I/O operation on closed file.
#   ❌ Error saving image at C303: I/O operation on closed file.
#   ❌ Error saving image at C304: I/O operation on closed file.
#   ❌ Error saving image at C305: I/O operation on closed file.
#   ❌ Error saving image at C306: I/O operation on closed file.
#   ❌ Error saving image at C307: I/O operation on closed file.
#   ❌ Error saving image at C308: I/O operation on closed file.
#   ❌ Error saving image at C309: I/O operation on closed file.
#   ❌ Error saving image at C310: I/O operation on closed file.
#   ❌ Error saving image at C311: I/O operation on closed file.
#   ❌ Error saving image at C312: I/O operation on closed file.
#   ❌ Error saving image at C313: I/O operation on closed file.
#   ❌ Error saving image at C314: I/O operation on closed file.
#   ❌ Error saving image at C315: I/O operation on closed file.
#   ❌ Error saving image at C316: I/O operation on closed file.
#   ❌ Error saving image at C317: I/O operation on closed file.
#   ❌ Error saving image at C318: I/O operation on closed file.
#   ❌ Error saving image at C319: I/O operation on closed file.
#   ❌ Error saving image at C320: I/O operation on closed file.
#   ❌ Error saving image at C321: I/O operation on closed file.
#   ❌ Error saving image at C322: I/O operation on closed file.
#   ❌ Error saving image at C323: I/O operation on closed file.
#   ❌ Error saving image at C324: I/O operation on closed file.
#   ❌ Error saving image at C325: I/O operation on closed file.
#   ❌ Error saving image at C326: I/O operation on closed file.
#   ❌ Error saving image at C327: I/O operation on closed file.
#   ❌ Error saving image at C328: I/O operation on closed file.
#   ❌ Error saving image at C329: I/O operation on closed file.
#   ❌ Error saving image at C330: I/O operation on closed file.
#   ❌ Error saving image at C331: I/O operation on closed file.
#   ❌ Error saving image at C332: I/O operation on closed file.
#   ❌ Error saving image at C333: I/O operation on closed file.
#   ❌ Error saving image at C334: I/O operation on closed file.
#   ❌ Error saving image at C335: I/O operation on closed file.
#   ❌ Error saving image at C336: I/O operation on closed file.
#   ❌ Error saving image at C337: I/O operation on closed file.
#   ❌ Error saving image at C338: I/O operation on closed file.
#   ❌ Error saving image at C339: I/O operation on closed file.
#   ❌ Error saving image at C340: I/O operation on closed file.
#   ❌ Error saving image at C341: I/O operation on closed file.
#   ❌ Error saving image at C342: I/O operation on closed file.
#   ❌ Error saving image at C343: I/O operation on closed file.
#   ❌ Error saving image at C344: I/O operation on closed file.
#   ❌ Error saving image at C345: I/O operation on closed file.
#   ❌ Error saving image at C346: I/O operation on closed file.
#   ❌ Error saving image at C347: I/O operation on closed file.
#   ❌ Error saving image at C348: I/O operation on closed file.
#   ❌ Error saving image at C349: I/O operation on closed file.
#   ❌ Error saving image at C350: I/O operation on closed file.
#   ❌ Error saving image at C351: I/O operation on closed file.
#   ❌ Error saving image at C352: I/O operation on closed file.
#   ❌ Error saving image at C353: I/O operation on closed file.
#   ❌ Error saving image at C354: I/O operation on closed file.
#   ❌ Error saving image at C355: I/O operation on closed file.
#   ❌ Error saving image at C356: I/O operation on closed file.
#   ❌ Error saving image at C357: I/O operation on closed file.
#   ❌ Error saving image at C358: I/O operation on closed file.
#   ❌ Error saving image at C359: I/O operation on closed file.
#   ❌ Error saving image at C360: I/O operation on closed file.
#   ❌ Error saving image at C361: I/O operation on closed file.
#   ❌ Error saving image at C362: I/O operation on closed file.
#   ❌ Error saving image at C363: I/O operation on closed file.
#   ❌ Error saving image at C364: I/O operation on closed file.
#   ❌ Error saving image at C365: I/O operation on closed file.
#   ❌ Error saving image at C366: I/O operation on closed file.
#   ❌ Error saving image at C367: I/O operation on closed file.
#   ❌ Error saving image at C368: I/O operation on closed file.
#   ❌ Error saving image at C369: I/O operation on closed file.
#   ❌ Error saving image at C370: I/O operation on closed file.
#   ❌ Error saving image at C371: I/O operation on closed file.
#   ❌ Error saving image at C372: I/O operation on closed file.
#   ❌ Error saving image at C373: I/O operation on closed file.
#   ❌ Error saving image at C374: I/O operation on closed file.
#   ❌ Error saving image at C375: I/O operation on closed file.
#   ❌ Error saving image at C376: I/O operation on closed file.
#   ❌ Error saving image at C377: I/O operation on closed file.
#   ❌ Error saving image at C378: I/O operation on closed file.
#   ❌ Error saving image at C379: I/O operation on closed file.
#   ❌ Error saving image at C380: I/O operation on closed file.
#   ❌ Error saving image at C381: I/O operation on closed file.
#   ❌ Error saving image at C382: I/O operation on closed file.
#   ❌ Error saving image at C383: I/O operation on closed file.
#   ❌ Error saving image at C384: I/O operation on closed file.
#   ❌ Error saving image at C385: I/O operation on closed file.
#   ❌ Error saving image at C386: I/O operation on closed file.
#   ❌ Error saving image at C387: I/O operation on closed file.
#   ❌ Error saving image at C388: I/O operation on closed file.
#   ❌ Error saving image at C389: I/O operation on closed file.
#   ❌ Error saving image at C390: I/O operation on closed file.
#   ❌ Error saving image at C391: I/O operation on closed file.
#   ❌ Error saving image at C392: I/O operation on closed file.
#   ❌ Error saving image at C393: I/O operation on closed file.
#   ❌ Error saving image at C394: I/O operation on closed file.
#   ❌ Error saving image at C395: I/O operation on closed file.
#   ❌ Error saving image at C396: I/O operation on closed file.
#   ❌ Error saving image at C397: I/O operation on closed file.
#   ❌ Error saving image at C398: I/O operation on closed file.
#   ❌ Error saving image at C399: I/O operation on closed file.
#   ❌ Error saving image at C400: I/O operation on closed file.
#   ❌ Error saving image at C401: I/O operation on closed file.
#   ❌ Error saving image at C402: I/O operation on closed file.
#   ❌ Error saving image at C403: I/O operation on closed file.
#   ❌ Error saving image at C404: I/O operation on closed file.
#   ❌ Error saving image at C405: I/O operation on closed file.
#   ❌ Error saving image at C406: I/O operation on closed file.
#   ❌ Error saving image at C407: I/O operation on closed file.
#   ❌ Error saving image at C408: I/O operation on closed file.
#   ❌ Error saving image at C409: I/O operation on closed file.
#   ❌ Error saving image at C410: I/O operation on closed file.
#   ❌ Error saving image at C411: I/O operation on closed file.
#   ❌ Error saving image at C412: I/O operation on closed file.
#   ❌ Error saving image at C413: I/O operation on closed file.
#   ❌ Error saving image at C414: I/O operation on closed file.
#   ❌ Error saving image at C415: I/O operation on closed file.
#   ❌ Error saving image at C416: I/O operation on closed file.
#   ❌ Error saving image at C417: I/O operation on closed file.
#   ❌ Error saving image at C418: I/O operation on closed file.
#   ❌ Error saving image at C419: I/O operation on closed file.
#   ❌ Error saving image at C420: I/O operation on closed file.
#   ❌ Error saving image at C421: I/O operation on closed file.
#   ❌ Error saving image at C422: I/O operation on closed file.
#   ❌ Error saving image at C423: I/O operation on closed file.
#   ❌ Error saving image at C424: I/O operation on closed file.
#   ❌ Error saving image at C425: I/O operation on closed file.
#   ❌ Error saving image at C426: I/O operation on closed file.
#   ❌ Error saving image at C427: I/O operation on closed file.
#   ❌ Error saving image at C428: I/O operation on closed file.
#   ❌ Error saving image at C429: I/O operation on closed file.
#   ❌ Error saving image at C430: I/O operation on closed file.
#   ❌ Error saving image at C431: I/O operation on closed file.
#   ❌ Error saving image at C432: I/O operation on closed file.
#   ❌ Error saving image at C433: I/O operation on closed file.
#   ❌ Error saving image at C434: I/O operation on closed file.
#   ❌ Error saving image at C435: I/O operation on closed file.
#   ❌ Error saving image at C436: I/O operation on closed file.
#   ❌ Error saving image at C437: I/O operation on closed file.
#   ❌ Error saving image at C438: I/O operation on closed file.
#   ❌ Error saving image at C439: I/O operation on closed file.
#   ❌ Error saving image at C440: I/O operation on closed file.
#   ❌ Error saving image at C441: I/O operation on closed file.
#   ❌ Error saving image at C442: I/O operation on closed file.
#   ❌ Error saving image at C443: I/O operation on closed file.
#   ❌ Error saving image at C444: I/O operation on closed file.
#   ❌ Error saving image at C445: I/O operation on closed file.
#   ❌ Error saving image at C446: I/O operation on closed file.
#   ❌ Error saving image at C447: I/O operation on closed file.
#   ❌ Error saving image at C448: I/O operation on closed file.
#   ❌ Error saving image at C449: I/O operation on closed file.
#   ❌ Error saving image at C450: I/O operation on closed file.
#   ❌ Error saving image at C451: I/O operation on closed file.
#   ❌ Error saving image at C452: I/O operation on closed file.
#   ❌ Error saving image at C453: I/O operation on closed file.
#   ❌ Error saving image at C454: I/O operation on closed file.
#   ❌ Error saving image at C455: I/O operation on closed file.
#   ❌ Error saving image at C456: I/O operation on closed file.
#   ❌ Error saving image at C457: I/O operation on closed file.
#   ❌ Error saving image at C458: I/O operation on closed file.
#   ❌ Error saving image at C459: I/O operation on closed file.
#   ❌ Error saving image at C460: I/O operation on closed file.
#   ❌ Error saving image at C461: I/O operation on closed file.
#   ❌ Error saving image at C462: I/O operation on closed file.
#   ❌ Error saving image at C463: I/O operation on closed file.
#   ❌ Error saving image at C464: I/O operation on closed file.
#   ❌ Error saving image at C465: I/O operation on closed file.
#   ❌ Error saving image at C466: I/O operation on closed file.
#   ❌ Error saving image at C467: I/O operation on closed file.
#   ❌ Error saving image at C468: I/O operation on closed file.
#   ❌ Error saving image at C469: I/O operation on closed file.
#   ❌ Error saving image at C470: I/O operation on closed file.
#   ❌ Error saving image at C471: I/O operation on closed file.
#   ❌ Error saving image at C472: I/O operation on closed file.
#   ❌ Error saving image at C473: I/O operation on closed file.
#   ❌ Error saving image at C474: I/O operation on closed file.
# Found 171 images in RAMBU columns
# Processing 171 images in column 'GAMBAR RAMBU'
#   ✅ Saved: Petunjuk Lokasi Rumah Sakit.png
#   ✅ Saved: Larangan Batas Kecepatan 40km.png
#   ✅ Saved: Penyempitan di Kanan Jalan.png
#   ✅ Saved: Petunjuk Arah Lokasi IGD 24 jam RSIA.png
#   ✅ Saved: Peringatan Hati-Hati.png
#   ✅ Saved: Peringatan “Kurangi Kecepatan Sekarang Ada Pekerjaan”.png
#   ⚠️ Duplicate 'Nama Rambu' found: Petunjuk Lokasi Rumah Sakit - Replacing existing image
#   ✅ Saved: Petunjuk Lokasi Rumah Sakit.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Hati-Hati - Replacing existing image
#   ✅ Saved: Peringatan Hati-Hati.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Hati-Hati - Replacing existing image
#   ✅ Saved: Peringatan Hati-Hati.png
#   ✅ Saved: Petunjuk Lokasi Fasilitas Penyeberangan Pejalan Kaki.png
#   ✅ Saved: Peringatan Banyak Lalu Lintas Pejalan Kaki Anak-anak.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Hati-Hati - Replacing existing image
#   ✅ Saved: Peringatan Hati-Hati.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Hati-Hati - Replacing existing image
#   ✅ Saved: Peringatan Hati-Hati.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Hati-Hati - Replacing existing image
#   ✅ Saved: Peringatan Hati-Hati.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Hati-Hati - Replacing existing image
#   ✅ Saved: Peringatan Hati-Hati.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Hati-Hati - Replacing existing image
#   ✅ Saved: Peringatan Hati-Hati.png
#   ✅ Saved: Peringatan Banyak Lalu Lintas Pejalan Kaki dan Petunjuk Lokasi Masjid.png
#   ✅ Saved: Peringatan Banyak Lalu Lintas Pejalan Kaki.png
#   ✅ Saved: RPPJ, Petunjuk Lokasi Sekolah dan Peringatan Banyak Lalu Lintas Pejalan Kaki Anak-anak.png
#   ❌ Error saving image at E25: I/O operation on closed file.
#   ✅ Saved: Peringatan Hati-Hati dan Peringatan Tikungan Tajam Ke Kiri.png
#   ❌ Error saving image at E27: I/O operation on closed file.
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Hati-Hati dan Peringatan Tikungan Tajam Ke Kiri - Replacing existing image
#   ✅ Saved: Peringatan Hati-Hati dan Peringatan Tikungan Tajam Ke Kiri.png
#   ✅ Saved: Larangan Parkir.png
#   ✅ Saved: Petunjuk Lokasi Masjid.png
#   ⚠️ Duplicate 'Nama Rambu' found: Larangan Parkir - Replacing existing image
#   ✅ Saved: Larangan Parkir.png
#   ⚠️ Duplicate 'Nama Rambu' found: Petunjuk Lokasi Fasilitas Penyeberangan Pejalan Kaki - Replacing existing image
#   ✅ Saved: Petunjuk Lokasi Fasilitas Penyeberangan Pejalan Kaki.png
#   ⚠️ Duplicate 'Nama Rambu' found: Larangan Parkir - Replacing existing image
#   ✅ Saved: Larangan Parkir.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Banyak Lalu Lintas Pejalan Kaki Anak-anak - Replacing existing image
#   ✅ Saved: Peringatan Banyak Lalu Lintas Pejalan Kaki Anak-anak.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Hati-Hati - Replacing existing image
#   ✅ Saved: Peringatan Hati-Hati.png
#   ✅ Saved: Peringatan Hati-Hati Keluar Masuk Kendaraan Pabrik Kecepatan Maksimal 40 Km.png
#   ⚠️ Duplicate 'Nama Rambu' found: Larangan Parkir - Replacing existing image
#   ✅ Saved: Larangan Parkir.png
#   ✅ Saved: Petunjuk Turun Naik Penumpang.png
#   ✅ Saved: Peringatan Turunan Landai dan Peringatan Jembatan.png
#   ✅ Saved: Peringatan Tanjakan Landai.png
#   ⚠️ Duplicate 'Nama Rambu' found: Peringatan Tanjakan Landai - Replacing existing image
#   ✅ Saved: Peringatan Tanjakan Landai.png
#   ⚠️ Duplicate 'Nama Rambu' found: Petunjuk Lokasi Fasilitas Penyeberangan Pejalan Kaki - Replacing existing image
#   ✅ Saved: Petunjuk Lokasi Fasilitas Penyeberangan Pejalan Kaki.png
#   ✅ Saved: Peringatan Jalan Bergelombang.png
#   ✅ Saved: Peringatan Hati-Hati Banyak Kendaraan Keluar Masuk.png
#   ✅ Saved: Peringatan Hati-hati Keluar Masuk Kendaraan Besar.png
#   ⚠️ Duplicate 'Nama Rambu' found: Larangan Parkir - Replacing existing image
#   ✅ Saved: Larangan Parkir.png
#   ✅ Saved: Larangan Berhenti.png
#   ✅ Saved: Larangan Putar Balik.png
#   ❌ Error saving image at E49: I/O operation on closed file.
#   ❌ Error saving image at E50: I/O operation on closed file.
#   ❌ Error saving image at E51: I/O operation on closed file.
#   ❌ Error saving image at E52: I/O operation on closed file.
#   ❌ Error saving image at E53: I/O operation on closed file.
#   ❌ Error saving image at E54: I/O operation on closed file.
#   ❌ Error saving image at E55: I/O operation on closed file.
#   ❌ Error saving image at E56: I/O operation on closed file.
#   ❌ Error saving image at E57: I/O operation on closed file.
#   ❌ Error saving image at E58: I/O operation on closed file.
#   ❌ Error saving image at E59: I/O operation on closed file.
#   ❌ Error saving image at E60: I/O operation on closed file.
#   ❌ Error saving image at E61: I/O operation on closed file.
#   ❌ Error saving image at E62: I/O operation on closed file.
#   ❌ Error saving image at E63: I/O operation on closed file.
#   ❌ Error saving image at E64: I/O operation on closed file.
#   ❌ Error saving image at E65: I/O operation on closed file.
#   ❌ Error saving image at E66: I/O operation on closed file.
#   ❌ Error saving image at E67: I/O operation on closed file.
#   ❌ Error saving image at E68: I/O operation on closed file.
#   ❌ Error saving image at E69: I/O operation on closed file.
#   ❌ Error saving image at E70: I/O operation on closed file.
#   ❌ Error saving image at E71: I/O operation on closed file.
#   ❌ Error saving image at E72: I/O operation on closed file.
#   ❌ Error saving image at E73: I/O operation on closed file.
#   ❌ Error saving image at E74: I/O operation on closed file.
#   ❌ Error saving image at E75: I/O operation on closed file.
#   ❌ Error saving image at E76: I/O operation on closed file.
#   ❌ Error saving image at E77: I/O operation on closed file.
#   ❌ Error saving image at E78: I/O operation on closed file.
#   ❌ Error saving image at E79: I/O operation on closed file.
#   ❌ Error saving image at E80: I/O operation on closed file.
#   ❌ Error saving image at E81: I/O operation on closed file.
#   ❌ Error saving image at E82: I/O operation on closed file.
#   ❌ Error saving image at E83: I/O operation on closed file.
#   ❌ Error saving image at E84: I/O operation on closed file.
#   ❌ Error saving image at E85: I/O operation on closed file.
#   ❌ Error saving image at E86: I/O operation on closed file.
#   ❌ Error saving image at E87: I/O operation on closed file.
#   ❌ Error saving image at E88: I/O operation on closed file.
#   ❌ Error saving image at E89: I/O operation on closed file.
#   ❌ Error saving image at E90: I/O operation on closed file.
#   ❌ Error saving image at E91: I/O operation on closed file.
#   ❌ Error saving image at E92: I/O operation on closed file.
#   ❌ Error saving image at E93: I/O operation on closed file.
#   ❌ Error saving image at E94: I/O operation on closed file.
#   ❌ Error saving image at E95: I/O operation on closed file.
#   ❌ Error saving image at E96: I/O operation on closed file.
#   ❌ Error saving image at E97: I/O operation on closed file.
#   ❌ Error saving image at E98: I/O operation on closed file.
#   ❌ Error saving image at E99: I/O operation on closed file.
#   ❌ Error saving image at E100: I/O operation on closed file.
#   ❌ Error saving image at E101: I/O operation on closed file.
#   ❌ Error saving image at E102: I/O operation on closed file.
#   ❌ Error saving image at E103: I/O operation on closed file.
#   ❌ Error saving image at E104: I/O operation on closed file.
#   ❌ Error saving image at E105: I/O operation on closed file.
#   ❌ Error saving image at E106: I/O operation on closed file.
#   ❌ Error saving image at E107: I/O operation on closed file.
#   ❌ Error saving image at E108: I/O operation on closed file.
#   ❌ Error saving image at E109: I/O operation on closed file.
#   ❌ Error saving image at E110: I/O operation on closed file.
#   ❌ Error saving image at E111: I/O operation on closed file.
#   ❌ Error saving image at E113: I/O operation on closed file.
#   ❌ Error saving image at E114: I/O operation on closed file.
#   ❌ Error saving image at E115: I/O operation on closed file.
#   ❌ Error saving image at E116: I/O operation on closed file.
#   ❌ Error saving image at E117: I/O operation on closed file.
#   ❌ Error saving image at E118: I/O operation on closed file.
#   ❌ Error saving image at E119: I/O operation on closed file.
#   ❌ Error saving image at E120: I/O operation on closed file.
#   ❌ Error saving image at E121: I/O operation on closed file.
#   ❌ Error saving image at E122: I/O operation on closed file.
#   ❌ Error saving image at E123: I/O operation on closed file.
#   ❌ Error saving image at E124: I/O operation on closed file.
#   ❌ Error saving image at E125: I/O operation on closed file.
#   ❌ Error saving image at E126: I/O operation on closed file.
#   ❌ Error saving image at E127: I/O operation on closed file.
#   ❌ Error saving image at E128: I/O operation on closed file.
#   ❌ Error saving image at E129: I/O operation on closed file.
#   ❌ Error saving image at E130: I/O operation on closed file.
#   ❌ Error saving image at E131: I/O operation on closed file.
#   ❌ Error saving image at E132: I/O operation on closed file.
#   ❌ Error saving image at E133: I/O operation on closed file.
#   ❌ Error saving image at E134: I/O operation on closed file.
#   ❌ Error saving image at E135: I/O operation on closed file.
#   ❌ Error saving image at E136: I/O operation on closed file.
#   ❌ Error saving image at E137: I/O operation on closed file.
#   ❌ Error saving image at E138: I/O operation on closed file.
#   ❌ Error saving image at E139: I/O operation on closed file.
#   ❌ Error saving image at E140: I/O operation on closed file.
#   ❌ Error saving image at E141: I/O operation on closed file.
#   ❌ Error saving image at E142: I/O operation on closed file.
#   ❌ Error saving image at E143: I/O operation on closed file.
#   ❌ Error saving image at E144: I/O operation on closed file.
#   ❌ Error saving image at E145: I/O operation on closed file.
#   ❌ Error saving image at E146: I/O operation on closed file.
#   ❌ Error saving image at E147: I/O operation on closed file.
#   ❌ Error saving image at E148: I/O operation on closed file.
#   ❌ Error saving image at E149: I/O operation on closed file.
#   ❌ Error saving image at E150: I/O operation on closed file.
#   ❌ Error saving image at E151: I/O operation on closed file.
#   ❌ Error saving image at E152: I/O operation on closed file.
#   ❌ Error saving image at E153: I/O operation on closed file.
#   ❌ Error saving image at E154: I/O operation on closed file.
#   ❌ Error saving image at E155: I/O operation on closed file.
#   ❌ Error saving image at E156: I/O operation on closed file.
#   ❌ Error saving image at E157: I/O operation on closed file.
#   ❌ Error saving image at E158: I/O operation on closed file.
#   ❌ Error saving image at E159: I/O operation on closed file.
#   ❌ Error saving image at E160: I/O operation on closed file.
#   ❌ Error saving image at E161: I/O operation on closed file.
#   ❌ Error saving image at E162: I/O operation on closed file.
#   ❌ Error saving image at E163: I/O operation on closed file.
#   ❌ Error saving image at E164: I/O operation on closed file.
#   ❌ Error saving image at E165: I/O operation on closed file.
#   ❌ Error saving image at E166: I/O operation on closed file.
#   ❌ Error saving image at E167: I/O operation on closed file.
#   ❌ Error saving image at E168: I/O operation on closed file.
#   ❌ Error saving image at E169: I/O operation on closed file.
#   ❌ Error saving image at E170: I/O operation on closed file.
#   ❌ Error saving image at E171: I/O operation on closed file.
#   ❌ Error saving image at E172: I/O operation on closed file.
#   ❌ Error saving image at E173: I/O operation on closed file.
#   ❌ Error saving image at E174: I/O operation on closed file.
#   ❌ Error saving image at E175: I/O operation on closed file.
#   ❌ Error saving image at E176: I/O operation on closed file.
#   ❌ Error saving image at E177: I/O operation on closed file.
# ✅ Completed sheet 'RAMBU':
#   - Dokumentasi: 30 images
#   - Rambu: 41 images
#   - RPPJ: 0 images
# Processing sheet 2/13: PJU
# Found 'Jenis Tiang' column: JENIS TIANG Pilih Salah Satu (Column M)
# Found 363 images in DOKUMENTASI columns
# Processing 363 images in column 'DOKUMENTASI'
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row6.png
#   ❌ Error saving image at C7: I/O operation on closed file.
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row8.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row9.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row10.png
#   ❌ Error saving image at C11: I/O operation on closed file.
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row12.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row13.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row14.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row15.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row16.png
#   ❌ Error saving image at C17: I/O operation on closed file.
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row18.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row19.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row20.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row21.png
#   ❌ Error saving image at C22: I/O operation on closed file.
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row23.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row24.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row25.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row26.png
#   ❌ Error saving image at C27: I/O operation on closed file.
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row28.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row29.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row30.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row31.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row32.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row33.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row34.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row35.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row36.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row37.png
#   ❌ Error saving image at C38: I/O operation on closed file.
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row39.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row40.png
#   ❌ Error saving image at C41: I/O operation on closed file.
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row42.png
#   ❌ Error saving image at C43: I/O operation on closed file.
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row44.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row45.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row46.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row47.png
#   ❌ Error saving image at C48: I/O operation on closed file.
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row49.png
#   ❌ Error saving image at C50: I/O operation on closed file.
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row51.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row52.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row53.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row54.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row55.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row56.png
#   ❌ Error saving image at C57: I/O operation on closed file.
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row58.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row59.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row60.png
#   ❌ Error saving image at C61: I/O operation on closed file.
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row62.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row63.png
#   ❌ Error saving image at C64: I/O operation on closed file.
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row65.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row66.png
#   ❌ Error saving image at C67: I/O operation on closed file.
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row68.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row69.png
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row70.png
#   ❌ Error saving image at C71: I/O operation on closed file.
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_PJU_Column_DOKUMENTASI_Row72.png
# ...
#   ❌ Error saving image at B7: I/O operation on closed file.
#   ❌ Error saving image at B8: I/O operation on closed file.
#   ❌ Error saving image at B9: I/O operation on closed file.
#   ❌ Error saving image at B10: I/O operation on closed file.
#   ❌ Error saving image at B11: I/O operation on closed file.
#   ❌ Error saving image at B12: I/O operation on closed file.
#   ❌ Error saving image at B14: I/O operation on closed file.
#   ❌ Error saving image at B15: I/O operation on closed file.
#   ❌ Error saving image at B16: I/O operation on closed file.
#   ❌ Error saving image at B18: I/O operation on closed file.
#   ❌ Error saving image at B23: I/O operation on closed file.
#   ❌ Error saving image at B39: I/O operation on closed file.
# ✅ Completed sheet 'WATER BARRIER':
#   - Dokumentasi: 0 images
#   - Rambu: 0 images
#   - RPPJ: 0 images
# Processing sheet 13/13: CERMIN TIKUNG
# Found 235 images in DOKUMENTASI columns
# Processing 235 images in column 'DOKUMENTASI'
#   ❌ Error saving image at C6: I/O operation on closed file.
#   ❌ Error saving image at C7: I/O operation on closed file.
#   ❌ Error saving image at C8: I/O operation on closed file.
#   ✅ Saved: 02. CILEUNGSI - CIBINONG (CITEUREUP)_Sheet_CERMIN TIKUNG_Column_DOKUMENTASI_Row9.png
#   ❌ Error saving image at C10: I/O operation on closed file.
#   ❌ Error saving image at C11: I/O operation on closed file.
#   ❌ Error saving image at C12: I/O operation on closed file.
#   ❌ Error saving image at C13: I/O operation on closed file.
#   ❌ Error saving image at C14: I/O operation on closed file.
#   ❌ Error saving image at C15: I/O operation on closed file.
#   ❌ Error saving image at C16: I/O operation on closed file.
#   ❌ Error saving image at C17: I/O operation on closed file.
#   ❌ Error saving image at C18: I/O operation on closed file.
#   ❌ Error saving image at C19: I/O operation on closed file.
#   ❌ Error saving image at C20: I/O operation on closed file.
#   ❌ Error saving image at C21: I/O operation on closed file.
#   ❌ Error saving image at C22: I/O operation on closed file.
#   ❌ Error saving image at C23: I/O operation on closed file.
#   ❌ Error saving image at C24: I/O operation on closed file.
#   ❌ Error saving image at C25: I/O operation on closed file.
#   ❌ Error saving image at C26: I/O operation on closed file.
#   ❌ Error saving image at C27: I/O operation on closed file.
#   ❌ Error saving image at C28: I/O operation on closed file.
#   ❌ Error saving image at C29: I/O operation on closed file.
#   ❌ Error saving image at C30: I/O operation on closed file.
#   ❌ Error saving image at C31: I/O operation on closed file.
#   ❌ Error saving image at C32: I/O operation on closed file.
#   ❌ Error saving image at C33: I/O operation on closed file.
#   ❌ Error saving image at C34: I/O operation on closed file.
#   ❌ Error saving image at C35: I/O operation on closed file.
#   ❌ Error saving image at C36: I/O operation on closed file.
#   ❌ Error saving image at C37: I/O operation on closed file.
#   ❌ Error saving image at C38: I/O operation on closed file.
#   ❌ Error saving image at C39: I/O operation on closed file.
#   ❌ Error saving image at C40: I/O operation on closed file.
#   ❌ Error saving image at C41: I/O operation on closed file.
#   ❌ Error saving image at C42: I/O operation on closed file.
#   ❌ Error saving image at C43: I/O operation on closed file.
#   ❌ Error saving image at C44: I/O operation on closed file.
#   ❌ Error saving image at C45: I/O operation on closed file.
#   ❌ Error saving image at C46: I/O operation on closed file.
#   ❌ Error saving image at C47: I/O operation on closed file.
#   ❌ Error saving image at C48: I/O operation on closed file.
#   ❌ Error saving image at C49: I/O operation on closed file.
#   ❌ Error saving image at C50: I/O operation on closed file.
#   ❌ Error saving image at C51: I/O operation on closed file.
#   ❌ Error saving image at C52: I/O operation on closed file.
#   ❌ Error saving image at C53: I/O operation on closed file.
#   ❌ Error saving image at C54: I/O operation on closed file.
#   ❌ Error saving image at C55: I/O operation on closed file.
#   ❌ Error saving image at C56: I/O operation on closed file.
#   ❌ Error saving image at C57: I/O operation on closed file.
#   ❌ Error saving image at C58: I/O operation on closed file.
#   ❌ Error saving image at C59: I/O operation on closed file.
#   ❌ Error saving image at C60: I/O operation on closed file.
#   ❌ Error saving image at C61: I/O operation on closed file.
#   ❌ Error saving image at C62: I/O operation on closed file.
#   ❌ Error saving image at C63: I/O operation on closed file.
#   ❌ Error saving image at C64: I/O operation on closed file.
#   ❌ Error saving image at C65: I/O operation on closed file.
#   ❌ Error saving image at C66: I/O operation on closed file.
#   ❌ Error saving image at C67: I/O operation on closed file.
#   ❌ Error saving image at C68: I/O operation on closed file.
#   ❌ Error saving image at C69: I/O operation on closed file.
#   ❌ Error saving image at C70: I/O operation on closed file.
#   ❌ Error saving image at C71: I/O operation on closed file.
#   ❌ Error saving image at C72: I/O operation on closed file.
#   ❌ Error saving image at C73: I/O operation on closed file.
#   ❌ Error saving image at C74: I/O operation on closed file.
#   ❌ Error saving image at C75: I/O operation on closed file.
#   ❌ Error saving image at C76: I/O operation on closed file.
#   ❌ Error saving image at C77: I/O operation on closed file.
#   ❌ Error saving image at C78: I/O operation on closed file.
#   ❌ Error saving image at C79: I/O operation on closed file.
#   ❌ Error saving image at C80: I/O operation on closed file.
#   ❌ Error saving image at C81: I/O operation on closed file.
#   ❌ Error saving image at C82: I/O operation on closed file.
#   ❌ Error saving image at C83: I/O operation on closed file.
#   ❌ Error saving image at C84: I/O operation on closed file.
#   ❌ Error saving image at C85: I/O operation on closed file.
#   ❌ Error saving image at C86: I/O operation on closed file.
#   ❌ Error saving image at C87: I/O operation on closed file.
#   ❌ Error saving image at C88: I/O operation on closed file.
#   ❌ Error saving image at C89: I/O operation on closed file.
#   ❌ Error saving image at C90: I/O operation on closed file.
#   ❌ Error saving image at C91: I/O operation on closed file.
#   ❌ Error saving image at C92: I/O operation on closed file.
#   ❌ Error saving image at C93: I/O operation on closed file.
#   ❌ Error saving image at C94: I/O operation on closed file.
#   ❌ Error saving image at C95: I/O operation on closed file.
#   ❌ Error saving image at C96: I/O operation on closed file.
#   ❌ Error saving image at C97: I/O operation on closed file.
#   ❌ Error saving image at C98: I/O operation on closed file.
#   ❌ Error saving image at C99: I/O operation on closed file.
#   ❌ Error saving image at C100: I/O operation on closed file.
#   ❌ Error saving image at C101: I/O operation on closed file.
#   ❌ Error saving image at C102: I/O operation on closed file.
#   ❌ Error saving image at C103: I/O operation on closed file.
#   ❌ Error saving image at C104: I/O operation on closed file.
#   ❌ Error saving image at C105: I/O operation on closed file.
#   ❌ Error saving image at C106: I/O operation on closed file.
#   ❌ Error saving image at C107: I/O operation on closed file.
#   ❌ Error saving image at C108: I/O operation on closed file.
#   ❌ Error saving image at C109: I/O operation on closed file.
#   ❌ Error saving image at C110: I/O operation on closed file.
#   ❌ Error saving image at C111: I/O operation on closed file.
#   ❌ Error saving image at C112: I/O operation on closed file.
#   ❌ Error saving image at C113: I/O operation on closed file.
#   ❌ Error saving image at C114: I/O operation on closed file.
#   ❌ Error saving image at C115: I/O operation on closed file.
#   ❌ Error saving image at C116: I/O operation on closed file.
#   ❌ Error saving image at C117: I/O operation on closed file.
#   ❌ Error saving image at C118: I/O operation on closed file.
#   ❌ Error saving image at C119: I/O operation on closed file.
#   ❌ Error saving image at C120: I/O operation on closed file.
#   ❌ Error saving image at C121: I/O operation on closed file.
#   ❌ Error saving image at C122: I/O operation on closed file.
#   ❌ Error saving image at C123: I/O operation on closed file.
#   ❌ Error saving image at C124: I/O operation on closed file.
#   ❌ Error saving image at C125: I/O operation on closed file.
#   ❌ Error saving image at C126: I/O operation on closed file.
#   ❌ Error saving image at C127: I/O operation on closed file.
#   ❌ Error saving image at C128: I/O operation on closed file.
#   ❌ Error saving image at C129: I/O operation on closed file.
#   ❌ Error saving image at C130: I/O operation on closed file.
#   ❌ Error saving image at C131: I/O operation on closed file.
#   ❌ Error saving image at C132: I/O operation on closed file.
#   ❌ Error saving image at C133: I/O operation on closed file.
#   ❌ Error saving image at C134: I/O operation on closed file.
#   ❌ Error saving image at C135: I/O operation on closed file.
#   ❌ Error saving image at C136: I/O operation on closed file.
#   ❌ Error saving image at C137: I/O operation on closed file.
#   ❌ Error saving image at C138: I/O operation on closed file.
#   ❌ Error saving image at C139: I/O operation on closed file.
#   ❌ Error saving image at C140: I/O operation on closed file.
#   ❌ Error saving image at C141: I/O operation on closed file.
#   ❌ Error saving image at C142: I/O operation on closed file.
#   ❌ Error saving image at C143: I/O operation on closed file.
#   ❌ Error saving image at C144: I/O operation on closed file.
#   ❌ Error saving image at C145: I/O operation on closed file.
#   ❌ Error saving image at C146: I/O operation on closed file.
#   ❌ Error saving image at C147: I/O operation on closed file.
#   ❌ Error saving image at C148: I/O operation on closed file.
#   ❌ Error saving image at C149: I/O operation on closed file.
#   ❌ Error saving image at C150: I/O operation on closed file.
#   ❌ Error saving image at C151: I/O operation on closed file.
#   ❌ Error saving image at C152: I/O operation on closed file.
#   ❌ Error saving image at C153: I/O operation on closed file.
#   ❌ Error saving image at C154: I/O operation on closed file.
#   ❌ Error saving image at C155: I/O operation on closed file.
#   ❌ Error saving image at C156: I/O operation on closed file.
#   ❌ Error saving image at C157: I/O operation on closed file.
#   ❌ Error saving image at C158: I/O operation on closed file.
#   ❌ Error saving image at C159: I/O operation on closed file.
#   ❌ Error saving image at C160: I/O operation on closed file.
#   ❌ Error saving image at C161: I/O operation on closed file.
#   ❌ Error saving image at C162: I/O operation on closed file.
#   ❌ Error saving image at C163: I/O operation on closed file.
#   ❌ Error saving image at C164: I/O operation on closed file.
#   ❌ Error saving image at C165: I/O operation on closed file.
#   ❌ Error saving image at C166: I/O operation on closed file.
#   ❌ Error saving image at C167: I/O operation on closed file.
#   ❌ Error saving image at C168: I/O operation on closed file.
#   ❌ Error saving image at C169: I/O operation on closed file.
#   ❌ Error saving image at C170: I/O operation on closed file.
#   ❌ Error saving image at C171: I/O operation on closed file.
#   ❌ Error saving image at C172: I/O operation on closed file.
#   ❌ Error saving image at C173: I/O operation on closed file.
#   ❌ Error saving image at C174: I/O operation on closed file.
#   ❌ Error saving image at C175: I/O operation on closed file.
#   ❌ Error saving image at C176: I/O operation on closed file.
#   ❌ Error saving image at C177: I/O operation on closed file.
#   ❌ Error saving image at C178: I/O operation on closed file.
#   ❌ Error saving image at C179: I/O operation on closed file.
#   ❌ Error saving image at C180: I/O operation on closed file.
#   ❌ Error saving image at C181: I/O operation on closed file.
#   ❌ Error saving image at C182: I/O operation on closed file.
#   ❌ Error saving image at C183: I/O operation on closed file.
#   ❌ Error saving image at C184: I/O operation on closed file.
#   ❌ Error saving image at C185: I/O operation on closed file.
#   ❌ Error saving image at C186: I/O operation on closed file.
#   ❌ Error saving image at C187: I/O operation on closed file.
#   ❌ Error saving image at C188: I/O operation on closed file.
#   ❌ Error saving image at C189: I/O operation on closed file.
#   ❌ Error saving image at C190: I/O operation on closed file.
#   ❌ Error saving image at C191: I/O operation on closed file.
#   ❌ Error saving image at C192: I/O operation on closed file.
#   ❌ Error saving image at C193: I/O operation on closed file.
#   ❌ Error saving image at C194: I/O operation on closed file.
#   ❌ Error saving image at C195: I/O operation on closed file.
#   ❌ Error saving image at C196: I/O operation on closed file.
#   ❌ Error saving image at C197: I/O operation on closed file.
#   ❌ Error saving image at C198: I/O operation on closed file.
#   ❌ Error saving image at C199: I/O operation on closed file.
#   ❌ Error saving image at C200: I/O operation on closed file.
#   ❌ Error saving image at C201: I/O operation on closed file.
#   ❌ Error saving image at C202: I/O operation on closed file.
#   ❌ Error saving image at C203: I/O operation on closed file.
#   ❌ Error saving image at C204: I/O operation on closed file.
#   ❌ Error saving image at C205: I/O operation on closed file.
#   ❌ Error saving image at C206: I/O operation on closed file.
#   ❌ Error saving image at C207: I/O operation on closed file.
#   ❌ Error saving image at C208: I/O operation on closed file.
#   ❌ Error saving image at C209: I/O operation on closed file.
#   ❌ Error saving image at C210: I/O operation on closed file.
#   ❌ Error saving image at C211: I/O operation on closed file.
#   ❌ Error saving image at C212: I/O operation on closed file.
#   ❌ Error saving image at C213: I/O operation on closed file.
#   ❌ Error saving image at C214: I/O operation on closed file.
#   ❌ Error saving image at C215: I/O operation on closed file.
#   ❌ Error saving image at C216: I/O operation on closed file.
#   ❌ Error saving image at C217: I/O operation on closed file.
#   ❌ Error saving image at C218: I/O operation on closed file.
#   ❌ Error saving image at C219: I/O operation on closed file.
#   ❌ Error saving image at C220: I/O operation on closed file.
#   ❌ Error saving image at C221: I/O operation on closed file.
#   ❌ Error saving image at C222: I/O operation on closed file.
#   ❌ Error saving image at C223: I/O operation on closed file.
#   ❌ Error saving image at C224: I/O operation on closed file.
#   ❌ Error saving image at C225: I/O operation on closed file.
#   ❌ Error saving image at C226: I/O operation on closed file.
#   ❌ Error saving image at C227: I/O operation on closed file.
#   ❌ Error saving image at C228: I/O operation on closed file.
#   ❌ Error saving image at C229: I/O operation on closed file.
#   ❌ Error saving image at C230: I/O operation on closed file.
#   ❌ Error saving image at C231: I/O operation on closed file.
#   ❌ Error saving image at C232: I/O operation on closed file.
#   ❌ Error saving image at C233: I/O operation on closed file.
#   ❌ Error saving image at C234: I/O operation on closed file.
#   ❌ Error saving image at C235: I/O operation on closed file.
#   ❌ Error saving image at C236: I/O operation on closed file.
#   ❌ Error saving image at C237: I/O operation on closed file.
#   ❌ Error saving image at C238: I/O operation on closed file.
#   ❌ Error saving image at C239: I/O operation on closed file.
#   ❌ Error saving image at C240: I/O operation on closed file.
# ✅ Completed sheet 'CERMIN TIKUNG':
#   - Dokumentasi: 1 images
#   - Rambu: 0 images
#   - RPPJ: 0 images
# ✅ Completed processing file: 02. CILEUNGSI - CIBINONG (CITEUREUP)
#   - 8/13 sheets processed
#   - 220 total images extracted
#
# ==================================================
# 📈 PROCESSING SUMMARY
# ==================================================
# Total files: 1
# Successfully processed: 1
# Failed to process: 0
# Images saved to: C:\Users\kanzi\Documents\Part Time Job\Hasil Export\Extract Images
#
# 🎉 All Excel files processing completed!
